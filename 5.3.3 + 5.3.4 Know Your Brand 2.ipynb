# %% [markdown]
# ## Step 1: Set up a Jupyter Notebook
# The aim of this section is to connect PostgreSQL with your Jupyter Notebook by leveraging Python Pandas. As mentioned earlier, you will need specific Python libraries to connect your Jupyter Notebook to PostgreSQL.
#
# You need to set up a conda environment (a directory that holds a collection of conda packages that you installed) on your computer with the Anaconda terminal. This will create the connection between PostgreSQL and Jupyter Notebook.
#
# Watch this video and follow along to learn the steps involved in creating a conda environment with Windows 10, but the instructions are similar for a Mac or Linux operating system. You can pause the video if needed to type in code snippets or go back to a previous timestamp if something is unclear. As long as, in the end, you understand and successfully set up the conda environment. In this video, you will learn how to:
#
# - set up the conda environment
# - install the necessary libraries into the conda environment
# - activate the conda environment.

# %% [markdown]
# Preparing the Conda environment is essential to have a smooth connection between PostgreSQL and your Jupyter Notebook.
#
# In case you are using Windows, navigate to the start menu and select the Anaconda terminal, also known as Anaconda Prompt. Type the following into the terminal;
# - conda create -n sql python
# - conda activate sql
# - conda install ipython-sql sqlalchemy psycopg2 notebook pandas -c conda-forge

# %% [markdown]
# ## Step 2: Import the Chinook database
# First, you have to inform the Jupyter Notebook that you will use SQL for this session. The ipython-sql library helps to load packages into the Jupyter Notebook and will not work in any other Python environment or IDE. It is specifically designed for Jupyter Notebook. The code snippet can be written as:
#
# - Indicate to Python to utilise SQL with the %load_ext sql command. The % is a Jupyter Notebook predefined function which allows us to replace traditional code snippets with more concise ones. It is also known as a magic command.
# - Import the operating system package (os).
# - Specify your PostgreSQL login details as:
#   - host='localhost'
#   - database='chinook'
#   - user='postgres'
#   -password= the password you set when you installed PostgreSQL.
# - Create a variable (connection_string) to store the connection request. Note that the connection string is the path to connect to an existing database with the specified password, username and hostname.
# - Specify the magic command (%sql) and ask for connection status with $connection_string. The output will indicate the connection status and the name of the database it has been connected to.
# - Execute the code.

# %%
# The % is a magic command in Jupyter Notebook, it helps to load packages.
# It will not work in a regular Python environment, only in Jupyter Notebook.
# When the % is used in front, it indicates the use of SQL.
# %load_ext sql

# Import operating system and the Anaconda environment.
import os

# PostgreSQL credentials.
host = 'localhost'
database = 'Chinook'
user = 'postgres'
# Your own password.
password = 'Pass123'     # Specify your own password.

# Test connection between PostgreSQL and Jupyter Notebook.
connection_string = f"postgresql://{user}:{password}@{host}/{database}"

# Determine connection status.
# %sql $connection_string
# Out:
# 'Connected: postgres@Chinook'

# %%
# clear old tables if rerunning all code
# %sql DROP TABLE artist_genre, genre_media, most_popular_artists, most_popular_artists
# Out:
#  * postgresql://postgres:***@localhost/Chinook
# (psycopg2.errors.UndefinedTable) table "artist_genre" does not exist
#
# [SQL: DROP TABLE artist_genre, genre_media, most_popular_artists, most_popular_artists]
# (Background on this error at: https://sqlalche.me/e/14/f405)

# %% [markdown]
# ### Confirm connection
# We've set up the conda environment and successfully connected it to the Chinook database. Let’s query the database to establish the connection and sense-check the database.
#
# Follow these prompts:
#
# - Indicate to Jupyter Notebook that you'll use SQL syntax with the %%sql command. Take note, there are two kinds of magic commands:
# - Line magic commands (start with %). This is where inputs are provided following the command in the same line. This is also a Modulo Operator that returns the remainder when dividing a left-hand operand by the right-hand operand.
# - Cell magic commands (start with %%). This is where the content in the entire cell becomes the input.
# - Specify the query with SQL syntax and the SELECT statement. Remember that if the column name includes a capital letter, you need to have double quotation marks ("") with SQL.
# - Query all the values FROM the Artist table, but LIMIT the query to 10 rows for illustrative purposes.

# %%
# The % is a magic command in Jupyter Notebook, it helps to load packages.
# %sql SELECT * from "Album" LIMIT 10
# Out:
#  * postgresql://postgres:***@localhost/Chinook
# 10 rows affected.
# [(1, 'For Those About To Rock We Salute You', 1),
#  (2, 'Balls to the Wall', 2),
#  (3, 'Restless and Wild', 2),
#  (4, 'Let There Be Rock', 1),
#  (5, 'Big Ones', 3),
#  (6, 'Jagged Little Pill', 4),
#  (7, 'Facelift', 5),
#  (8, 'Warner 25 Anos', 6),
#  (9, 'Plays Metallica By Four Cellos', 7),
#  (10, 'Audioslave', 8)]

# %%
# The % is a magic command in Jupyter Notebook, it helps to load packages.
# %sql SELECT * from "Customer" Limit 10
# Out:
#  * postgresql://postgres:***@localhost/Chinook
# 10 rows affected.
# [(1, 'Luís', 'Gonçalves', 'Embraer - Empresa Brasileira de Aeronáutica S.A.', 'Av. Brigadeiro Faria Lima, 2170', 'São José dos Campos', 'SP', 'Brazil', '12227-000', '+55 (12) 3923-5555', '+55 (12) 3923-5566', 'luisg@embraer.com.br', 3),
#  (2, 'Leonie', 'Köhler', None, 'Theodor-Heuss-Straße 34', 'Stuttgart', None, 'Germany', '70174', '+49 0711 2842222', None, 'leonekohler@surfeu.de', 5),
#  (3, 'François', 'Tremblay', None, '1498 rue Bélanger', 'Montréal', 'QC', 'Canada', 'H2G 1A7', '+1 (514) 721-4711', None, 'ftremblay@gmail.com', 3),
#  (4, 'Bjørn', 'Hansen', None, 'Ullevålsveien 14', 'Oslo', None, 'Norway', '0171', '+47 22 44 22 22', None, 'bjorn.hansen@yahoo.no', 4),
#  (5, 'Franti\x9aek', 'Wichterlová', 'JetBrains s.r.o.', 'Klanova 9/506', 'Prague', None, 'Czech Republic', '14700', '+420 2 4172 5555', '+420 2 4172 5555', 'frantisekw@jetbrains.com', 4),
#  (6, 'Helena', 'Holý', None, 'Rilská 3174/6', 'Prague', None, 'Czech Republic', '14300', '+420 2 4177 0449', None, 'hholy@gmail.com', 5),
#  (7, 'Astrid', 'Gruber', None, 'Rotenturmstraße 4, 1010 Innere Stadt', 'Vienne', None, 'Austria', '1010', '+43 01 5134505', None, 'astrid.gruber@apple.at', 5),
#  (8, 'Daan', 'Peeters', None, 'Grétrystraat 63', 'Brussels', None, 'Belgium', '1000', '+32 02 219 03 03', None, 'daan_peeters@apple.be', 4),
#  (9, 'Kara', 'Nielsen', None, 'Sønder Boulevard 51', 'Copenhagen', None, 'Denmark', '1720', '+453 3331 9991', None, 'kara.nielsen@jubii.dk', 4),
#  (10, 'Eduardo', 'Martins', 'Woodstock Discos', 'Rua Dr. Falcão Filho, 155', 'São Paulo', 'SP', 'Brazil', '01007-010', '+55 (11) 3033-5446', '+55 (11) 3033-4564', 'eduardo@woodstock.com.br', 4)]

# %%
# practice - retrieve the "Genre" table
# %sql SELECT * from "Genre" Limit 15
# Out:
#  * postgresql://postgres:***@localhost/Chinook
# 15 rows affected.
# [(1, 'Rock'),
#  (2, 'Jazz'),
#  (3, 'Metal'),
#  (4, 'Alternative & Punk'),
#  (5, 'Rock And Roll'),
#  (6, 'Blues'),
#  (7, 'Latin'),
#  (8, 'Reggae'),
#  (9, 'Pop'),
#  (10, 'Soundtrack'),
#  (11, 'Bossa Nova'),
#  (12, 'Easy Listening'),
#  (13, 'Heavy Metal'),
#  (14, 'R&B/Soul'),
#  (15, 'Electronica/Dance')]

# %% [markdown]
# ### sqlalchemy
# The sqlalchemy library is another tool to establish a connection between PostgreSQL and Jupyter Notebook. This library can help you to perform better data analysis by, for example, combining the power of Pandas. First, you have to establish an engine to ensure a connection. Follow these prompts:
#
# - Import create_engine from sqlalchemy.
# - Specify a name for the new engine you are creating and link it to the connection_string you created with the ipython-sql library. This is another example of writing Pythonic code.
# - Import the inspect package from sqlalchemy. This will help with querying the database. In this example, we want to determine the names of all the tables within the Chinook database.
# - Hint: If you get an error message, simply rerun the code snippet. Python has to connect to PostgreSQL and then return the output. A small break in communication might result in an error message.

# %%
# Import necessary libraries to create an engine.
from sqlalchemy import create_engine

# Name the engine.
engine = create_engine(connection_string)

# Import inspect.
from sqlalchemy import inspect

insp = inspect(engine)
insp.get_table_names()
# Out:
# ['Artist',
#  'Album',
#  'Employee',
#  'Customer',
#  'Invoice',
#  'InvoiceLine',
#  'Track',
#  'Playlist',
#  'PlaylistTrack',
#  'Genre',
#  'MediaType',
#  'new_customer',
#  'new_records',
#  'mos_popular_artists',
#  'peerreview']

# %% [markdown]
# ### Confirm connection II
# How and when does Pandas come into play? You can use Pandas to create a DataFrame directly from the Chinook database. Why is that important? If you have a Pandas DataFrame, you can tap into Python’s visualisation libraries and other data analysis tools. Follow these prompts for an example:
#
# - Import the Pandas library because you are working in a new environment.
# - Specify the name of the DataFrame you want to create.
# - Indicate to Pandas where to get the raw data from with the pd.read_sql() function.
# - Specify the SELECT statement, inside the brackets, to query the table directly from PostgreSQL. (Hint: The SQL syntax needs to be in quotation marks to be passed as a string.)
# - Remember to specify the engine you created as a connector between PostgreSQL and Jupyter Notebook.
# - Print the DataFrame.

# %%
# Import Pandas.
import pandas as pd

# Create a DataFrame.
df = pd.read_sql('SELECT * from "Artist" LIMIT 10', engine)

# View the DataFrame.
df
# Out:
#    ArtistId                  Name
# 0         1                 AC/DC
# 1         2                Accept
# 2         3             Aerosmith
# 3         4     Alanis Morissette
# 4         5       Alice In Chains
# 5         6  Antônio Carlos Jobim
# 6         7          Apocalyptica
# 7         8            Audioslave
# 8         9              BackBeat
# 9        10          Billy Cobham

# %%
# Create a DataFrame.
customer_df = pd.read_sql('SELECT * from "Customer" LIMIT 10', engine)

# View the DataFrame.
customer_df
# Out:
#    CustomerId  FirstName     LastName  \
# 0           1       Luís    Gonçalves
# 1           2     Leonie       Köhler
# 2           3   François     Tremblay
# 3           4      Bjørn       Hansen
# 4           5  Frantiek  Wichterlová
# 5           6     Helena         Holý
# 6           7     Astrid       Gruber
# 7           8       Daan      Peeters
# 8           9       Kara      Nielsen
# 9          10    Eduardo      Martins
#
#                                             Company  \
# 0  Embraer - Empresa Brasileira de Aeronáutica S.A.
# 1                                              None
# 2                                              None
# 3                                              None
# 4                                  JetBrains s.r.o.
# 5                                              None
# 6                                              None
# 7                                              None
# 8                                              None
# 9                                  Woodstock Discos
#
#                                 Address                 City State  \
# 0       Av. Brigadeiro Faria Lima, 2170  São José dos Campos    SP
# 1               Theodor-Heuss-Straße 34            Stuttgart  None
# 2                     1498 rue Bélanger             Montréal    QC
# 3                      Ullevålsveien 14                 Oslo  None
# 4                         Klanova 9/506               Prague  None
# 5                         Rilská 3174/6               Prague  None
# 6  Rotenturmstraße 4, 1010 Innere Stadt               Vienne  None
# 7                       Grétrystraat 63             Brussels  None
# 8                   Sønder Boulevard 51           Copenhagen  None
# 9             Rua Dr. Falcão Filho, 155            São Paulo    SP
#
#           Country PostalCode               Phone                 Fax  \
# 0          Brazil  12227-000  +55 (12) 3923-5555  +55 (12) 3923-5566
# 1         Germany      70174    +49 0711 2842222                None
# 2          Canada    H2G 1A7   +1 (514) 721-4711                None
# 3          Norway       0171     +47 22 44 22 22                None
# 4  Czech Republic      14700    +420 2 4172 5555    +420 2 4172 5555
# 5  Czech Republic      14300    +420 2 4177 0449                None
# 6         Austria       1010      +43 01 5134505                None
# 7         Belgium       1000    +32 02 219 03 03                None
# 8         Denmark       1720      +453 3331 9991                None
# 9          Brazil  01007-010  +55 (11) 3033-5446  +55 (11) 3033-4564
#
#                       Email  SupportRepId
# 0      luisg@embraer.com.br             3
# 1     leonekohler@surfeu.de             5
# 2       ftremblay@gmail.com             3
# 3     bjorn.hansen@yahoo.no             4
# 4  frantisekw@jetbrains.com             4
# 5           hholy@gmail.com             5
# 6    astrid.gruber@apple.at             5
# 7     daan_peeters@apple.be             4
# 8     kara.nielsen@jubii.dk             4
# 9  eduardo@woodstock.com.br             4

# %%
# Create a DataFrame.
genre_df = pd.read_sql('SELECT * from "Genre" LIMIT 10', engine)

# View the DataFrame.
genre_df
# Out:
#    GenreId                Name
# 0        1                Rock
# 1        2                Jazz
# 2        3               Metal
# 3        4  Alternative & Punk
# 4        5       Rock And Roll
# 5        6               Blues
# 6        7               Latin
# 7        8              Reggae
# 8        9                 Pop
# 9       10          Soundtrack

# %%
# Export data as CSV.
genre_df.to_csv('genre_df.csv')
customer_df.to_csv('customer_df.csv')

# %% [markdown]
# ## Apply Your Learning
# Let’s use basic SQL syntax to query the Chinook database by utilising the connection you created earlier with the ipython-sql, sqlalchemy and psycopg2 libraries between PostgreSQL and Jupyter Notebook.
#
# You'll construct three tables with basic SQL syntax in your Jupyter Notebook. The main aim of this exercise is to illustrate how to use SQL commands in combination with Python.

# %% [markdown]
# #### Construct a table indicating the first name, last name, and country of customers.
# The three columns are all present in the Customer table. Therefore, you can use the SELECT statement to query the Customer table. The code snippet will be:
#
# - Indicate to Python that you want to use SQL commands with %%sql.
# - Specify the column names that you query (FirstName, LastName, and Country) with the SELECT statement.
# - Use the FROM clause to specify the table as Customer.
# - For illustrative purposes, LIMIT the query to 10 rows.

# %%
# %%sql
#
# SELECT "FirstName", "LastName", "Country"
# FROM "Customer"
# LIMIT 10
# Out:
#  * postgresql://postgres:***@localhost/Chinook
# 10 rows affected.
# [('Luís', 'Gonçalves', 'Brazil'),
#  ('Leonie', 'Köhler', 'Germany'),
#  ('François', 'Tremblay', 'Canada'),
#  ('Bjørn', 'Hansen', 'Norway'),
#  ('Franti\x9aek', 'Wichterlová', 'Czech Republic'),
#  ('Helena', 'Holý', 'Czech Republic'),
#  ('Astrid', 'Gruber', 'Austria'),
#  ('Daan', 'Peeters', 'Belgium'),
#  ('Kara', 'Nielsen', 'Denmark'),
#  ('Eduardo', 'Martins', 'Brazil')]

# %% [markdown]
# Look at that! You have a table with the FirstName, LastName and Country. There is one difference between the Jupyter Notebook code snippet and the pgAdmin SQL syntax. Can you spot the difference? Whenever you refer to a table in pgAdmin, you have to use public.table_name. Rerun the query with FROM public."Customer". What do you see?
#
# Can you use the concat() function and combine the FirstName and LastName columns into a FullName column?

# %%
# %%sql
#
# SELECT CONCAT("FirstName", ' ', "LastName") AS "FullName", "Country"
# FROM "Customer"
# LIMIT 10
# Out:
#  * postgresql://postgres:***@localhost/Chinook
# 10 rows affected.
# [('Luís Gonçalves', 'Brazil'),
#  ('Leonie Köhler', 'Germany'),
#  ('François Tremblay', 'Canada'),
#  ('Bjørn Hansen', 'Norway'),
#  ('Franti\x9aek Wichterlová', 'Czech Republic'),
#  ('Helena Holý', 'Czech Republic'),
#  ('Astrid Gruber', 'Austria'),
#  ('Daan Peeters', 'Belgium'),
#  ('Kara Nielsen', 'Denmark'),
#  ('Eduardo Martins', 'Brazil')]

# %% [markdown]
# #### Determine the total of all the invoices generated during December 2009.
# What if you want to determine the total amount of sales for December 2009? You will only need to query one table, Invoice, and the code snippet will be:
#
# - Specify the SQL commands with %%sql.
# - Specify that you want the SUM of the Total column with the SELECT statement.
# - Use the FROM clause to specify the table as Invoice.
# - Specify the dates with the BETWEEN and AND clauses.

# %%
# %%sql
#
# SELECT SUM("Total")
# FROM "Invoice"
# WHERE "InvoiceDate" BETWEEN '01/12/2009' AND '31/12/2009'
# Out:
#  * postgresql://postgres:***@localhost/Chinook
# 1 rows affected.
# [(Decimal('37.62'),)]

# %% [markdown]
# Well done! The total amount of sales for December 2009 was $37.62. It doesn't seem high, but remember it was more than 12 years ago. Can you write a query to answer the following question?
#
# Which year had the most sales in December?

# %%
# %%sql
#
# SELECT date_part('year', "InvoiceDate") AS year, date_part('month', "InvoiceDate") AS month, SUM("Total")
# FROM "Invoice"
# WHERE date_part('month', "InvoiceDate") = 12
# GROUP BY year, month;
# Out:
#  * postgresql://postgres:***@localhost/Chinook
# 5 rows affected.
# [(2009.0, 12.0, Decimal('37.62')),
#  (2010.0, 12.0, Decimal('37.62')),
#  (2011.0, 12.0, Decimal('37.62')),
#  (2012.0, 12.0, Decimal('37.62')),
#  (2013.0, 12.0, Decimal('38.62'))]

# %% [markdown]
# #### Construct a table to indicate the composer for each track and runtime in milliseconds.
# There are a lot of tracks and each of them has a composer and runtime in milliseconds. The columns Composer, Name, and Milliseconds of the tracks are in the Track table. To construct a table indicating the composer and runtime of each track, do the following:
#
# - Specify the SQL commands with %%sql.
# - Specify that you want the columns Name, Composer, and Milliseconds with the SELECT statement.
# - Use the FROM clause to specify the table as Track.
# - Specify how the results table should be grouped with the GROUP BY function as Name, Composer and Milliseconds.
# - The ORDER BY will indicate how the results table will be sorted.

# %%
# %%sql
#
# SELECT "Name", "Composer", "Milliseconds"
# FROM "Track"
# GROUP BY "Name", "Composer", "Milliseconds"
# ORDER BY "Composer" DESC
# LIMIT 10
# Out:
#  * postgresql://postgres:***@localhost/Chinook
# 10 rows affected.
# [('The Real Problem', None, 11650),
#  ('Geração Coca-Cola (Ao Vivo)', None, 228153),
#  ('Se...', None, 286432),
#  ('Um Certo Alguém', None, 194063),
#  ('Nossa Gente (Avisa Là)', None, 188212),
#  ('Samba Pra Endrigo', None, 259265),
#  ('13 Years Of Grief', None, 246987),
#  ('Branch Closing', None, 1814855),
#  ('Oi, La', None, 167053),
#  ('País Tropical', None, 452519)]

# %% [markdown]
# Congratulations! Using LIMIT the table was limited to 10 rows for illustrative purposes. Can you see that the composers are indicated as None? If you run the same query in pgAdmin, the absence of composers will be [null].
#
# Can you determine the composer with the most tracks and longest runtime?

# %%
# %%sql
#
# SELECT "Composer", COUNT("Composer")
# FROM "Track"
# GROUP BY "Composer"
# ORDER BY COUNT("Composer") DESC
# LIMIT 10
# Out:
#  * postgresql://postgres:***@localhost/Chinook
# 10 rows affected.
# [('Steve Harris', 80),
#  ('U2', 44),
#  ('Jagger/Richards', 35),
#  ('Billy Corgan', 31),
#  ('Kurt Cobain', 26),
#  ('Bill Berry-Peter Buck-Mike Mills-Michael Stipe', 25),
#  ('The Tea Party', 24),
#  ('Chris Cornell', 23),
#  ('Miles Davis', 23),
#  ('Chico Science', 23)]

# %% [markdown]
# Track/Composer combo with longest run time

# %%
# %%sql
#
# SELECT "Name", "Composer", "Milliseconds"
# FROM "Track"
# GROUP BY "Name", "Composer", "Milliseconds"
# ORDER BY "Milliseconds" DESC
# LIMIT 10
# Out:
#  * postgresql://postgres:***@localhost/Chinook
# 10 rows affected.
# [('Occupation / Precipice', None, 5286953),
#  ('Through a Looking Glass', None, 5088838),
#  ('Greetings from Earth, Pt. 1', None, 2960293),
#  ('The Man With Nine Lives', None, 2956998),
#  ('Battlestar Galactica, Pt. 2', None, 2956081),
#  ('Battlestar Galactica, Pt. 1', None, 2952702),
#  ('Murder On the Rising Star', None, 2935894),
#  ('Battlestar Galactica, Pt. 3', None, 2927802),
#  ('Take the Celestra', None, 2927677),
#  ('Fire In Space', None, 2926593)]

# %% [markdown]
# Total runtime by Composer, all tracks

# %%
# %%sql
#
# SELECT "Composer", sum("Milliseconds") as "total_milliseconds"
# FROM "Track"
# GROUP BY "Composer"
# ORDER BY sum("Milliseconds") DESC
# LIMIT 10
# Out:
#  * postgresql://postgres:***@localhost/Chinook
# 10 rows affected.
# [(None, 695840650),
#  ('Steve Harris', 27217126),
#  ('U2', 11271816),
#  ('Miles Davis', 8996378),
#  ('Jagger/Richards', 8667178),
#  ('Billy Corgan', 7912553),
#  ('The Tea Party', 6579763),
#  ('Bill Berry-Peter Buck-Mike Mills-Michael Stipe', 6395130),
#  ('Chris Robinson/Rich Robinson', 6059094),
#  ('Chris Cornell', 5866463)]

# %% [markdown]
# #### Are you ready for a challenge? Would you be able to write a code snippet querying the Chinook database by yourself?
# How many tracks have a runtime of fewer than 1,000,000 milliseconds?

# %%
# %%sql
#
# SELECT COUNT("Milliseconds")
# FROM "Track"
# WHERE "Milliseconds" < 1000000
# Out:
#  * postgresql://postgres:***@localhost/Chinook
# 1 rows affected.
# [(3288,)]

# %% [markdown]
# ## 5.3.4 Part II
# Ryan, a data analyst with Know-your-Brand, is busy developing a machine learning (ML) model. The Chinook database is perfect to use as an example of a historical database. If the team can develop code that can provide answers to similar questions posed by Know-your-Brand, Ryan can develop the ML model based on the Chinook database. The ML model can then be tested on real data from Know-your-Brand. Therefore, Ryan asks you to answer the following questions:
#
# - Who are the 15 most popular artists?
# - What is the most sought genre based on media type?
# - Which artist is the most popular based on genre?
#
# Remember to break down a business question into smaller pieces. Just like a puzzle!

# %% [markdown]
# #### Question 1: Who are the 15 most popular artists?
# This seems like a straightforward question. We need to rank the artist from most popular to least popular. However, there are no specifics on how to rank them. Do we have to rank the artists based on sales (invoices), number of tracks or number of albums?
#
# The InvoiceLine table has a foreign key (FK) with the Track table, while the Track table is connected to the Album table with an FK. Lastly, the Album table is connected to the Artist table with an FK. The answer to this question does not seem that straightforward anymore. Let’s break it down into smaller parts.
#
# The main question is to determine the 15 most popular artists. Therefore, we need the names of the artists. The Artist table only has two columns: ArtistId and Name. To determine the 15 most popular artists according to albums released, simply join the Artist and Album tables. The joined table will also give us the Title of the albums. However, it may be more accurate to determine the popularity of artists based on tracks released. The number of tracks on an album can differ. Therefore, we have to join the Track table as well. In essence, we will need to JOIN four different tables.
#
# The code snippet can be written as follows:
#
# - Start with %%sql indicating to Jupyter Notebook that we are using SQL syntax.
# - Specify the CREATE TABLE command to create a new table. This is only for future references and a good practice to get used to. This ensures that we don’t have to rewrite the query every time we want to return the specified table.
# - Start the query with the SELECT statement indicating the specified column names we are interested in. In this example, we need the ArtistId, Name of the artist and album Title.
# - Use the aggregate functions (COUNT and SUM) to filter the results. We are interested in the number of artists (SUM(ArtistId)).
# - The FROM clause indicates the table we want to use as the starting point.
# - Specify each of the tables we want to JOIN with the USING clause indicating the FK.
# - Remember to use GROUP BY to indicate how the results table should be organised (column names to be displayed).
# - Finally, the ORDER BY clause indicates how to sort the results table.
# - Remember to use aliases to write more concise and precise syntax.

# %%
# %%sql
#
# CREATE TABLE most_popular_artists AS
# SELECT "ArtistId", "Artist"."Name", SUM("Quantity") AS "TracksSold"
# FROM "Artist"
# INNER JOIN "Album" USING ("ArtistId")
# INNER JOIN "Track" USING ("AlbumId")
# INNER JOIN "InvoiceLine" USING ("TrackId")
# GROUP BY "ArtistId", "Artist"."Name"
# ORDER BY SUM("Quantity") DESC
# Out:
#  * postgresql://postgres:***@localhost/Chinook
# 165 rows affected.
# []

# %% [markdown]
# This is the given answer i dont think its right as it breaks tracke by album and thats not the question is it plus also why would you sum Artist ID that just makes no sense

# %%
# %%sql
# SELECT ar."ArtistId", ar."Name", al."Title",
# COUNT(*),
# SUM(ar."ArtistId")
# FROM "Artist" ar
# JOIN "Album" al USING ("ArtistId")
# JOIN "Track" tr USING ("AlbumId")
# JOIN "InvoiceLine" i USING ("TrackId")
# GROUP BY ar."ArtistId", ar."Name", al."Title"
# ORDER BY COUNT(ar."ArtistId") DESC;
# Out:
#  * postgresql://postgres:***@localhost/Chinook
# 304 rows affected.
# [(17, 'Chico Buarque', 'Minha Historia', 27, 459),
#  (100, 'Lenny Kravitz', 'Greatest Hits', 26, 2600),
#  (81, 'Eric Clapton', 'Unplugged', 25, 2025),
#  (146, 'Titãs', 'Acústico', 22, 3212),
#  (52, 'Kiss', 'Greatest Kiss', 20, 1040),
#  (76, 'Creedence Clearwater Revival', 'Chronicle, Vol. 2', 19, 1444),
#  (144, 'The Who', 'My Generation - The Very Best Of The Who', 19, 2736),
#  (16, 'Caetano Veloso', 'Prenda Minha', 19, 304),
#  (113, 'Os Paralamas Do Sucesso', 'Acústico MTV', 18, 2034),
#  (158, 'Battlestar Galactica (Classic)', 'Battlestar Galactica (Classic), Season 1', 18, 2844),
#  (76, 'Creedence Clearwater Revival', 'Chronicle, Vol. 1', 18, 1368),
#  (54, 'Green Day', 'International Superhits', 18, 972),
#  (150, 'U2', 'Rattle And Hum', 17, 2550),
#  (88, "Guns N' Roses", 'Use Your Illusion I', 17, 1496),
#  (69, 'Gene Krupa', "Up An' Atom", 17, 1173),
#  (124, 'R.E.M.', 'The Best Of R.E.M.: The IRS Years', 17, 2108),
#  (18, 'Chico Science & Nação Zumbi', 'Afrociberdelia', 16, 288),
#  (156, 'The Office', 'The Office, Season 3', 16, 2496),
#  (150, 'U2', 'Instant Karma: The Amnesty International Campaign to Save Darfur', 16, 2400),
#  (132, 'Soundgarden', 'A-Sides', 15, 1980),
#  (70, 'Toquinho & Vinícius', 'Vinícius De Moraes - Sem Limite', 15, 1050),
#  (113, 'Os Paralamas Do Sucesso', 'Arquivo Os Paralamas Do Sucesso', 15, 1695),
#  (81, 'Eric Clapton', 'The Cream Of Clapton', 15, 1215),
#  (6, 'Antônio Carlos Jobim', 'Chill: Brazil (Disc 2)', 15, 90),
#  (54, 'Green Day', 'American Idiot', 15, 810),
#  (51, 'Queen', 'Greatest Hits II', 14, 714),
#  (124, 'R.E.M.', 'New Adventures In Hi-Fi', 14, 1736),
#  (148, 'Heroes', 'Heroes, Season 1', 13, 1924),
#  (111, 'O Terço', 'Compositores', 13, 1443),
#  (82, 'Faith No More', 'Album Of The Year', 13, 1066),
#  (149, 'Lost', 'Lost, Season 2', 13, 1937),
#  (82, 'Faith No More', 'Angel Dust', 13, 1066),
#  (27, 'Gilberto Gil', 'Quanta Gente Veio Ver (Live)', 13, 351),
#  (131, 'Smashing Pumpkins', 'Rotten Apples: Greatest Hits', 13, 1703),
#  (41, 'Elis Regina', 'Elis Regina-Minha História', 13, 533),
#  (252, 'Amy Winehouse', 'Back to Black', 12, 3024),
#  (145, 'Tim Maia', 'Serie Sem Limite (Disc 1)', 12, 1740),
#  (50, 'Metallica', 'ReLoad', 12, 600),
#  (113, 'Os Paralamas Do Sucesso', 'Arquivo II', 12, 1356),
#  (14, 'Bruce Dickinson', 'Chemical Wedding', 12, 168),
#  (146, 'Titãs', 'Volume Dois', 12, 1752),
#  (147, 'Battlestar Galactica', 'Battlestar Galactica, Season 3', 12, 1764),
#  (135, 'System Of A Down', 'Mezmerize', 12, 1620),
#  (50, 'Metallica', 'Garage Inc. (Disc 2)', 12, 600),
#  (91, 'James Brown', 'Sex Machine', 12, 1092),
#  (51, 'Queen', 'News Of The World', 12, 612),
#  (77, 'Cássia Eller', 'Cássia Eller - Coleção Sem Limite [Disc 2]', 12, 924),
#  (145, 'Tim Maia', 'Serie Sem Limite (Disc 2)', 12, 1740),
#  (150, 'U2', 'The Best Of 1980-1990', 11, 1650),
#  (150, 'U2', 'B-Sides 1980-1990', 11, 1650),
#  (131, 'Smashing Pumpkins', 'Judas 0: B-Sides and Rarities', 11, 1441),
#  (53, 'Spyro Gyra', 'Heart of the Night', 11, 583),
#  (50, 'Metallica', "Kill 'Em All", 11, 550),
#  (50, 'Metallica', 'Load', 11, 550),
#  (51, 'Queen', 'Greatest Hits I', 11, 561),
#  (52, 'Kiss', 'Unplugged [Live]', 11, 572),
#  (90, 'Iron Maiden', 'The X Factor', 11, 990),
#  (13, 'Body Count', 'Body Count', 11, 143),
#  (21, 'Various Artists', 'Vozes do MPB', 11, 231),
#  (150, 'U2', 'War', 11, 1650),
#  (149, 'Lost', 'Lost, Season 3', 11, 1639),
#  (152, 'Van Halen', 'The Best Of Van Halen, Vol. I', 10, 1520),
#  (126, 'Raul Seixas', 'Raul Seixas', 10, 1260),
#  (3, 'Aerosmith', 'Big Ones', 10, 30),
#  (50, 'Metallica', 'Master Of Puppets', 10, 500),
#  (88, "Guns N' Roses", 'Use Your Illusion II', 10, 880),
#  (1, 'AC/DC', 'For Those About To Rock We Salute You', 10, 10),
#  (134, 'Stone Temple Pilots', 'Core', 10, 1340),
#  (22, 'Led Zeppelin', 'BBC Sessions [Disc 2] [Live]', 10, 220),
#  (98, 'Judas Priest', 'Living After Midnight', 10, 980),
#  (143, 'The Tea Party', 'Tangents', 10, 1430),
#  (114, 'Ozzy Osbourne', 'Tribute', 10, 1140),
#  (112, 'Olodum', 'Olodum', 10, 1120),
#  (127, 'Red Hot Chili Peppers', 'Blood Sugar Sex Magik', 10, 1270),
#  (150, 'U2', 'Pop', 10, 1500),
#  (150, 'U2', 'How To Dismantle An Atomic Bomb', 10, 1500),
#  (138, 'The Clash', 'The Singles', 10, 1380),
#  (85, 'Frank Sinatra', 'My Way: The Best Of Frank Sinatra [Disc 1]', 10, 850),
#  (149, 'Lost', 'Lost, Season 1', 10, 1490),
#  (104, 'Marvin Gaye', 'Seek And Shall Find: More Of The Best (1963-1981)', 10, 1040),
#  (90, 'Iron Maiden', 'Seventh Son of a Seventh Son', 9, 810),
#  (80, 'Djavan', 'Djavan Ao Vivo - Vol. 1', 9, 720),
#  (90, 'Iron Maiden', 'Powerslave', 9, 810),
#  (127, 'Red Hot Chili Peppers', 'Californication', 9, 1143),
#  (53, 'Spyro Gyra', 'Morning Dance', 9, 477),
#  (90, 'Iron Maiden', 'The Number of The Beast', 9, 810),
#  (121, 'Planet Hemp', 'Os Cães Ladram Mas A Caravana Não Pára', 9, 1089),
#  (22, 'Led Zeppelin', 'Led Zeppelin I', 9, 198),
#  (77, 'Cássia Eller', 'Cássia Eller - Sem Limite [Disc 1]', 9, 693),
#  (89, 'Incognito', 'Blue Moods', 9, 801),
#  (50, 'Metallica', 'Black Album', 9, 450),
#  (133, 'Stevie Ray Vaughan & Double Trouble', 'In Step', 9, 1197),
#  (82, 'Faith No More', 'King For A Day Fool For A Lifetime', 9, 738),
#  (22, 'Led Zeppelin', 'Led Zeppelin III', 9, 198),
#  (122, 'R.E.M. Feat. Kate Pearson', 'Out Of Time', 9, 1098),
#  (80, 'Djavan', 'Djavan Ao Vivo - Vol. 02', 9, 720),
#  (88, "Guns N' Roses", 'Appetite for Destruction', 9, 792),
#  (116, 'Passengers', 'Original Soundtracks 1', 9, 1044),
#  (56, 'Gonzaguinha', 'Meus Momentos', 9, 504),
#  (19, 'Cidade Negra', 'Acústico MTV [Live]', 9, 171),
#  (18, 'Chico Science & Nação Zumbi', 'Da Lama Ao Caos', 9, 162),
#  (155, 'Zeca Pagodinho', 'Ao Vivo [IMPORT]', 9, 1395),
#  (139, 'The Cult', 'Pure Cult: The Best Of The Cult (For Rockers, Ravers, Lovers & Sinners) [UK]', 9, 1251),
#  (22, 'Led Zeppelin', 'Led Zeppelin II', 9, 198),
#  (118, 'Pearl Jam', 'Live On Two Legs [Live]', 9, 1062),
#  (150, 'U2', 'Zooropa', 9, 1350),
#  (99, 'Legião Urbana', 'A TempestadeTempestade Ou O Livro Dos Dias', 9, 891),
#  (105, 'Men At Work', 'The Best Of Men At Work', 8, 840),
#  (87, 'Godsmack', 'Faceless', 8, 696),
#  (90, 'Iron Maiden', 'Rock In Rio [CD1]', 8, 720),
#  (103, 'Marisa Monte', 'Barulhinho Bom', 8, 824),
#  (99, 'Legião Urbana', 'Mais Do Mesmo', 8, 792),
#  (94, 'Jimi Hendrix', 'Are You Experienced?', 8, 752),
#  (57, 'Os Mutantes', 'Minha História', 8, 456),
#  (90, 'Iron Maiden', 'Rock In Rio [CD2]', 8, 720),
#  (115, 'Page & Plant', 'Walking Into Clarksdale', 8, 920),
#  (22, 'Led Zeppelin', 'In Through The Out Door', 8, 176),
#  (90, 'Iron Maiden', 'No Prayer For The Dying', 8, 720),
#  (127, 'Red Hot Chili Peppers', 'By The Way', 8, 1016),
#  (180, 'House Of Pain', 'House of Pain', 8, 1440),
#  (55, 'David Coverdale', 'Into The Light', 8, 440),
#  (86, 'Funk Como Le Gusta', 'Roda De Funk', 8, 688),
#  (83, 'Falamansa', 'Deixa Entrar', 8, 664),
#  (4, 'Alanis Morissette', 'Jagged Little Pill', 8, 32),
#  (42, 'Milton Nascimento', 'Milton Nascimento Ao Vivo', 8, 336),
#  (90, 'Iron Maiden', 'Live After Death', 8, 720),
#  (151, 'UB40', 'UB40 The Best Of - Volume Two [UK]', 8, 1208),
#  (124, 'R.E.M.', 'Green', 8, 992),
#  (101, 'Lulu Santos', 'Lulu Santos - RCA 100 Anos De Música - Álbum 01', 8, 808),
#  (12, 'Black Sabbath', 'Black Sabbath Vol. 4 (Remaster)', 7, 84),
#  (5, 'Alice In Chains', 'Facelift', 7, 35),
#  (142, 'The Rolling Stones', 'Voodoo Lounge', 7, 994),
#  (141, 'The Police', 'The Police Greatest Hits', 7, 987),
#  (50, 'Metallica', 'St. Anger', 7, 350),
#  (19, 'Cidade Negra', 'Cidade Negra - Hits', 7, 133),
#  (6, 'Antônio Carlos Jobim', 'Warner 25 Anos', 7, 42),
#  (15, 'Buddy Guy', 'The Best Of Buddy Guy - The Millenium Collection', 7, 105),
#  (50, 'Metallica', 'Garage Inc. (Disc 1)', 7, 350),
#  (110, 'Nirvana', 'From The Muddy Banks Of The Wishkah [Live]', 7, 770),
#  (82, 'Faith No More', 'The Real Thing', 7, 574),
#  (92, 'Jamiroquai', 'Synkronized', 7, 644),
#  (137, 'The Black Crowes', 'Live [Disc 1]', 7, 959),
#  (109, 'Mötley Crüe', 'Motley Crue Greatest Hits', 7, 763),
#  (118, 'Pearl Jam', 'Riot Act', 7, 826),
#  (36, 'O Rappa', 'Radio Brasil (O Som da Jovem Vanguarda) - Seleccao de Henrique Amaro', 7, 252),
#  (114, 'Ozzy Osbourne', 'Speak of the Devil', 7, 798),
#  (24, 'Marcos Valle', 'Chill: Brazil (Disc 1)', 7, 168),
#  (68, 'Miles Davis', 'Miles Ahead', 7, 476),
#  (139, 'The Cult', 'Beyond Good And Evil', 7, 973),
#  (42, 'Milton Nascimento', 'Minas', 7, 294),
#  (143, 'The Tea Party', 'Transmission', 7, 1001),
#  (90, 'Iron Maiden', 'Virtual XI', 7, 630),
#  (137, 'The Black Crowes', 'Live [Disc 2]', 7, 959),
#  (78, 'Def Leppard', "Vault: Def Leppard's Greatest Hits", 7, 546),
#  (149, 'Lost', 'LOST, Season 4', 7, 1043),
#  (93, 'JET', 'Get Born', 7, 651),
#  (90, 'Iron Maiden', 'A Real Dead One', 7, 630),
#  (125, 'Raimundos', 'Cesta Básica', 7, 875),
#  (22, 'Led Zeppelin', 'Houses Of The Holy', 7, 154),
#  (152, 'Van Halen', 'Diver Down', 7, 1064),
#  (118, 'Pearl Jam', 'Vs.', 6, 708),
#  (252, 'Amy Winehouse', 'Frank', 6, 1512),
#  (59, 'Santana', 'Supernatural', 6, 354),
#  (118, 'Pearl Jam', 'Pearl Jam', 6, 708),
#  (106, 'Motörhead', 'Ace Of Spades', 6, 636),
#  (96, 'Jota Quest', 'Jota Quest-1995', 6, 576),
#  (97, 'João Suplicy', 'Cafezinho', 6, 582),
#  (142, 'The Rolling Stones', 'No Security', 6, 852),
#  (90, 'Iron Maiden', 'A Matter of Life and Death', 6, 540),
#  (9, 'BackBeat', 'BackBeat Soundtrack', 6, 54),
#  (37, 'Ed Motta', 'The Best of Ed Motta', 6, 222),
#  (46, 'Jorge Ben', 'Jorge Ben Jor 25 Anos', 6, 276),
#  (90, 'Iron Maiden', 'Brave New World', 6, 540),
#  (152, 'Van Halen', 'Van Halen III', 6, 912),
#  (72, 'Vinícius De Moraes', 'Vinicius De Moraes', 6, 432),
#  (22, 'Led Zeppelin', 'IV', 6, 132),
#  (153, 'Velvet Revolver', 'Contraband', 6, 918),
#  (68, 'Miles Davis', 'The Essential Miles Davis [Disc 1]', 6, 408),
#  (150, 'U2', "All That You Can't Leave Behind", 6, 900),
#  (152, 'Van Halen', 'Van Halen', 6, 912),
#  (8, 'Audioslave', 'Audioslave', 6, 48),
#  (108, 'Mônica Marianno', 'Demorou...', 6, 648),
#  (21, 'Various Artists', 'Carnaval 2001', 6, 126),
#  (21, 'Various Artists', 'Sambas De Enredo 2001', 6, 126),
#  (90, 'Iron Maiden', 'Live At Donington 1992 (Disc 2)', 6, 540),
#  (22, 'Led Zeppelin', 'BBC Sessions [Disc 1] [Live]', 6, 132),
#  (21, 'Various Artists', 'Axé Bahia 2001', 6, 126),
#  (128, 'Rush', 'Retrospective I (1974-1980)', 6, 768),
#  (22, 'Led Zeppelin', 'Coda', 6, 132),
#  (156, 'The Office', 'The Office, Season 2', 6, 936),
#  (130, 'Skank', 'Maquinarama', 6, 780),
#  (1, 'AC/DC', 'Let There Be Rock', 6, 6),
#  (50, 'Metallica', 'Ride The Lightning', 6, 300),
#  (50, 'Metallica', '...And Justice For All', 6, 300),
#  (84, 'Foo Fighters', 'In Your Honor [Disc 2]', 6, 504),
#  (92, 'Jamiroquai', 'Emergency On Planet Earth', 6, 552),
#  (84, 'Foo Fighters', 'The Colour And The Shape', 6, 504),
#  (150, 'U2', 'Achtung Baby', 6, 900),
#  (58, 'Deep Purple', 'The Battle Rages On', 5, 290),
#  (136, 'Terry Bozzio, Tony Levin & Steve Stevens', '[1997] Black Light Syndrome', 5, 680),
#  (22, 'Led Zeppelin', 'Physical Graffiti [Disc 2]', 5, 110),
#  (110, 'Nirvana', 'Nevermind', 5, 550),
#  (90, 'Iron Maiden', 'Somewhere in Time', 5, 450),
#  (58, 'Deep Purple', 'Purpendicular', 5, 290),
#  (142, 'The Rolling Stones', 'Hot Rocks, 1964-1971 (Disc 1)', 5, 710),
#  (8, 'Audioslave', 'Revelations', 5, 40),
#  (90, 'Iron Maiden', 'Dance Of Death', 5, 450),
#  (58, 'Deep Purple', 'Come Taste The Band', 5, 290),
#  (90, 'Iron Maiden', 'Fear Of The Dark', 5, 450),
#  (20, 'Cláudio Zoli', 'Na Pista', 5, 100),
#  (90, 'Iron Maiden', 'Killers', 5, 450),
#  (22, 'Led Zeppelin', 'Presence', 5, 110),
#  (101, 'Lulu Santos', 'Lulu Santos - RCA 100 Anos De Música - Álbum 02', 5, 505),
#  (58, 'Deep Purple', "Knocking at Your Back Door: The Best Of Deep Purple in the 80's", 5, 290),
#  (84, 'Foo Fighters', 'One By One', 5, 420),
#  (8, 'Audioslave', 'Out Of Exile', 5, 40),
#  (179, 'Scorpions', '20th Century Masters - The Millennium Collection: The Best of Scorpions', 5, 895),
#  (90, 'Iron Maiden', 'Piece Of Mind', 5, 450),
#  (90, 'Iron Maiden', 'A Real Live One', 5, 450),
#  (27, 'Gilberto Gil', 'As Canções de Eu Tu Eles', 5, 135),
#  (84, 'Foo Fighters', 'In Your Honor [Disc 1]', 5, 420),
#  (11, 'Black Label Society', 'Alcohol Fueled Brewtality Live! [Disc 1]', 5, 55),
#  (102, 'Marillion', 'Misplaced Childhood', 5, 510),
#  (117, "Paul D'Ianno", 'The Beast Live', 5, 585),
#  (92, 'Jamiroquai', 'The Return Of The Space Cowboy', 5, 460),
#  (7, 'Apocalyptica', 'Plays Metallica By Four Cellos', 4, 28),
#  (68, 'Miles Davis', 'The Essential Miles Davis [Disc 2]', 4, 272),
#  (58, 'Deep Purple', 'MK III The Final Concerts [Disc 1]', 4, 232),
#  (204, 'Temple of the Dog', 'Temple of the Dog', 4, 816),
#  (58, 'Deep Purple', 'Slaves And Masters', 4, 232),
#  (130, 'Skank', 'O Samba Poconé', 4, 520),
#  (58, 'Deep Purple', 'Machine Head', 4, 232),
#  (90, 'Iron Maiden', 'Iron Maiden', 4, 360),
#  (140, 'The Doors', 'The Doors', 4, 560),
#  (58, 'Deep Purple', 'Fireball', 4, 232),
#  (58, 'Deep Purple', 'Stormbringer', 4, 232),
#  (23, 'Frank Zappa & Captain Beefheart', 'Bongo Fury', 4, 92),
#  (118, 'Pearl Jam', 'Ten', 4, 472),
#  (120, 'Pink Floyd', 'Dark Side Of The Moon', 4, 480),
#  (95, 'Joe Satriani', 'Surfing with the Alien (Remastered)', 4, 380),
#  (205, 'Chris Cornell', 'Carry On', 4, 820),
#  (10, 'Billy Cobham', 'The Best Of Billy Cobham', 4, 40),
#  (90, 'Iron Maiden', 'Live At Donington 1992 (Disc 1)', 4, 360),
#  (79, 'Dennis Chambers', 'Outbreak', 4, 316),
#  (11, 'Black Label Society', 'Alcohol Fueled Brewtality Live! [Disc 2]', 3, 33),
#  (59, 'Santana', 'Santana - As Years Go By', 3, 177),
#  (22, 'Led Zeppelin', 'The Song Remains The Same (Disc 1)', 3, 66),
#  (156, 'The Office', 'The Office, Season 1', 3, 468),
#  (58, 'Deep Purple', 'Deep Purple In Rock', 3, 174),
#  (2, 'Accept', 'Restless and Wild', 3, 6),
#  (59, 'Santana', 'Santana Live', 3, 177),
#  (114, 'Ozzy Osbourne', 'No More Tears (Remastered)', 3, 342),
#  (257, 'Academy of St. Martin in the Fields, Sir Neville Marriner & Thurston Dart', 'Bach: Orchestral Suites Nos. 1 - 4', 2, 514),
#  (22, 'Led Zeppelin', 'Physical Graffiti [Disc 1]', 2, 44),
#  (22, 'Led Zeppelin', 'The Song Remains The Same (Disc 2)', 2, 44),
#  (2, 'Accept', 'Balls to the Wall', 2, 4),
#  (12, 'Black Sabbath', 'Black Sabbath', 2, 24),
#  (245, 'Michael Tilson Thomas & San Francisco Symphony', 'Berlioz: Symphonie Fantastique', 2, 490),
#  (114, 'Ozzy Osbourne', 'Diary of a Madman (Remastered)', 2, 228),
#  (272, 'Emerson String Quartet', "Schubert: The Late String Quartets & String Quintet (3 CD's)", 2, 544),
#  (263, 'Equale Brass Ensemble, John Eliot Gardiner & Munich Monteverdi Orchestra and Choir', 'Purcell: Music for the Queen Mary', 2, 526),
#  (16, 'Caetano Veloso', 'Sozinho Remix Ao Vivo', 2, 32),
#  (27, 'Gilberto Gil', 'Quanta Gente Veio ver--Bônus De Carnaval', 2, 54),
#  (233, 'Chicago Symphony Orchestra & Fritz Reiner', 'Scheherazade', 2, 466),
#  (159, 'Aquaman', 'Aquaman', 2, 318),
#  (248, 'Berliner Philharmoniker & Herbert Von Karajan', 'Mozart: Symphonies Nos. 40 & 41', 1, 248),
#  (255, 'Yehudi Menuhin', 'Bartok: Violin & Viola Concertos', 1, 255),
#  (238, 'Maurizio Pollini', 'Beethoven Piano Sonatas: Moonlight & Pastorale', 1, 238),
#  (226, 'Eugene Ormandy', 'Holst: The Planets, Op. 32 & Vaughan Williams: Fantasies', 1, 226),
#  (198, 'Habib Koité and Bamada', 'Muso Ko', 1, 198),
#  (254, 'Otto Klemperer & Philharmonia Orchestra', "Beethoven: Symphony No. 6 'Pastoral' Etc.", 1, 254),
#  (201, 'Luciana Souza/Romero Lubambo', 'Duos II', 1, 201),
#  (221, 'Sir Georg Solti & Wiener Philharmoniker', 'Wagner: Favourite Overtures', 1, 221),
#  (242, 'Edo de Waart & San Francisco Symphony', 'Adams, John: The Chairman Dances', 1, 242),
#  (237, 'Berliner Philharmoniker & Hans Rosbaud', 'Sibelius: Finlandia', 1, 237),
#  (114, 'Ozzy Osbourne', 'Bark at the Moon (Remastered)', 1, 114),
#  (248, 'Berliner Philharmoniker & Herbert Von Karajan', 'Grieg: Peer Gynt Suites & Sibelius: Pelléas et Mélisande', 1, 248),
#  (256, 'Philharmonia Orchestra & Sir Neville Marriner', "Mendelssohn: A Midsummer Night's Dream", 1, 256),
#  (217, 'Royal Philharmonic Orchestra & Sir Thomas Beecham', 'Haydn: Symphonies 99 - 104', 1, 217),
#  (213, 'Scholars Baroque Ensemble', 'Handel: The Messiah (Highlights)', 1, 213),
#  (157, 'Dread Zeppelin', 'Un-Led-Ed', 1, 157),
#  (243, 'Antal Doráti & London Symphony Orchestra', "Tchaikovsky: 1812 Festival Overture, Op.49, Capriccio Italien & Beethoven: Wellington's Victory", 1, 243),
#  (222, 'Academy of St. Martin in the Fields, John Birch, Sir Neville Marriner & Sylvia McNair', 'Fauré: Requiem, Ravel: Pavane & Others', 1, 222),
#  (266, 'Martin Roscoe', 'Szymanowski: Piano Works, Vol. 1', 1, 266),
#  (234, 'Orchestra of The Age of Enlightenment', 'Bach: The Brandenburg Concertos', 1, 234),
#  (245, 'Michael Tilson Thomas & San Francisco Symphony', 'Prokofiev: Romeo & Juliet', 1, 245),
#  (247, "The King's Singers", 'English Renaissance', 1, 247),
#  (253, 'Calexico', 'Carried to Dust (Bonus Track Version)', 1, 253),
#  (235, 'Emanuel Ax, Eugene Ormandy & Philadelphia Orchestra', 'Chopin: Piano Concertos Nos. 1 & 2', 1, 235),
#  (260, 'Adrian Leaper & Doreen de Feis', 'Górecki: Symphony No. 3', 1, 260),
#  (269, 'Michele Campanella', "Liszt - 12 Études D'Execution Transcendante", 1, 269),
#  (267, 'Göteborgs Symfoniker & Neeme Järvi', 'Nielsen: The Six Symphonies', 1, 267),
#  (208, 'English Concert & Trevor Pinnock', 'Pachelbel: Canon & Gigue', 1, 208),
#  (212, 'Yo-Yo Ma', 'Bach: The Cello Suites', 1, 212),
#  (114, 'Ozzy Osbourne', 'Blizzard of Ozz', 1, 114),
#  (200, 'The Posies', 'Every Kind of Light', 1, 200),
#  (58, 'Deep Purple', 'The Final Concerts (Disc 2)', 1, 58),
#  (214, 'Academy of St. Martin in the Fields & Sir Neville Marriner', 'The World of Classical Favourites', 1, 214),
#  (265, 'Julian Bream', 'J.S. Bach: Chaconne, Suite in E Minor, Partita in E Major & Prelude, Fugue and Allegro', 1, 265),
#  (261, 'Roger Norrington, London Classical Players', 'Purcell: The Fairy Queen', 1, 261),
#  (241, 'Felix Schmidt, London Symphony Orchestra & Rafael Frühbeck de Burgos', 'Elgar: Cello Concerto & Vaughan Williams: Fantasias', 1, 241),
#  (226, 'Eugene Ormandy', 'Respighi:Pines of Rome', 1, 226),
#  (259, 'The 12 Cellists of The Berlin Philharmonic', 'South American Getaway', 1, 259),
#  (264, "Kent Nagano and Orchestre de l'Opéra de Lyon", 'Weill: The Seven Deadly Sins', 1, 264)]

# %%
# Import the SQL query to pandas
import pandas as pd

# Create a DataFrame
q1 = pd.read_sql('SELECT * FROM most_popular_artists', engine)

# View the output.
q1
# Out:
#      ArtistId                                               Name  TracksSold
# 0          90                                        Iron Maiden         140
# 1         150                                                 U2         107
# 2          50                                          Metallica          91
# 3          22                                       Led Zeppelin          87
# 4         113                            Os Paralamas Do Sucesso          45
# ..        ...                                                ...         ...
# 160       214  Academy of St. Martin in the Fields & Sir Nevi...           1
# 161       157                                     Dread Zeppelin           1
# 162       222  Academy of St. Martin in the Fields, John Birc...           1
# 163       247                                 The King's Singers           1
# 164       260                     Adrian Leaper & Doreen de Feis           1
#
# [165 rows x 3 columns]

# %%
# Export data as CSV.
q1.to_csv('q1.csv')

# %% [markdown]
# #### Question 2: What is the most sought genre based on the media type?
# This question asks us to determine the most popular genre based on the media type. From the start, it looks like we will only need two tables: Genre and MediaType. Unfortunately, there is no key between these two tables. The only table that has both genre and media type as column names is the Track table. Seems like we have to JOIN three tables!
#
# The code snippet can be written as follows:
#
# - Start with %%sql indicating to Jupyter Notebook that we are using SQL syntax.
# - Specify the CREATE TABLE command to create a new table for future reference.
# - Start the query with the SELECT statement indicating the specified column names we are interested in. In this example, we need the GenreId, Name of the Genre and MediaType Name. There are two columns with the name 'Name'. Can we still remember how to distinguish between them? (Hint: Use aliases.)
# - Use the aggregate functions (COUNT and SUM) to filter the results.
# - The FROM clause indicates the table we want to use as the starting point.
# - Specify the tables we want to JOIN with the USING clause indicating the key(s).
# - Remember to use GROUP BY to indicate how the results table should be organised (column names to be displayed).
# - Employ aliases to write more concise and precise syntax.
# - Finally, the ORDER BY clause indicates how to sort the results table.

# %%
# %%sql
#
# CREATE TABLE genre_media AS
# SELECT COUNT(g."GenreId"), m."MediaTypeId", m."Name" AS "MediaName", g."Name" AS "GenreName"
# FROM "Genre" g
# INNER JOIN "Track" t USING ("GenreId")
# INNER JOIN "MediaType" m USING ("MediaTypeId")
# GROUP BY m. "MediaTypeId", m."Name", g."Name"
# ORDER BY COUNT("GenreId") DESC
# Out:
#  * postgresql://postgres:***@localhost/Chinook
# 38 rows affected.
# []

# %%
# Create a DataFrame.
q2 = pd.read_sql('SELECT * FROM genre_media', engine)

# View the output.
q2
# Out:
#     count  MediaTypeId                    MediaName           GenreName
# 0    1211            1              MPEG audio file                Rock
# 1     578            1              MPEG audio file               Latin
# 2     374            1              MPEG audio file               Metal
# 3     332            1              MPEG audio file  Alternative & Punk
# 4     127            1              MPEG audio file                Jazz
# 5      93            3  Protected MPEG-4 video file            TV Shows
# 6      84            2     Protected AAC audio file                Rock
# 7      81            1              MPEG audio file               Blues
# 8      67            2     Protected AAC audio file           Classical
# 9      64            3  Protected MPEG-4 video file               Drama
# 10     58            1              MPEG audio file              Reggae
# 11     49            1              MPEG audio file            R&B/Soul
# 12     42            1              MPEG audio file          Soundtrack
# 13     38            2     Protected AAC audio file         Alternative
# 14     35            1              MPEG audio file         Hip Hop/Rap
# 15     34            2     Protected AAC audio file                 Pop
# 16     28            1              MPEG audio file   Electronica/Dance
# 17     28            1              MPEG audio file         Heavy Metal
# 18     26            1              MPEG audio file               World
# 19     26            3  Protected MPEG-4 video file    Sci Fi & Fantasy
# 20     24            1              MPEG audio file      Easy Listening
# 21     17            3  Protected MPEG-4 video file              Comedy
# 22     15            1              MPEG audio file          Bossa Nova
# 23     14            1              MPEG audio file                 Pop
# 24     13            3  Protected MPEG-4 video file     Science Fiction
# 25     12            1              MPEG audio file       Rock And Roll
# 26     12            2     Protected AAC audio file            R&B/Soul
# 27      6            4     Purchased AAC audio file           Classical
# 28      3            5               AAC audio file                Jazz
# 29      2            5               AAC audio file   Electronica/Dance
# 30      2            5               AAC audio file                Rock
# 31      2            5               AAC audio file               World
# 32      1            3  Protected MPEG-4 video file         Alternative
# 33      1            4     Purchased AAC audio file         Alternative
# 34      1            2     Protected AAC audio file          Soundtrack
# 35      1            5               AAC audio file           Classical
# 36      1            2     Protected AAC audio file               Opera
# 37      1            5               AAC audio file               Latin

# %% [markdown]
# #### Question 3: Which artist is the most popular based on genre?
# Now, we need to determine the most popular artist based on genre. From the start, it looks like we will only need two tables: Genre and Artist. Again, there is no key between these two tables. The Artist and Album tables are connected with a key, while the Genre, Track and Album tables are connected with keys. Seems like we have to JOIN four tables!
#
# The code snippet can be written similar to Questions 1 and 2:
#
# - Start with %%sql indicating to Jupyter Notebook that we are using SQL syntax.
# - Specify the CREATE TABLE command to create a new table for future reference.
# - Start the query with the SELECT statement indicating the specified column.
# - Use the aggregate functions (COUNT and SUM) to filter the results.
# - The FROM clause indicates the table we want to use as the starting point.
# - Specify the tables we want to JOIN with the USING clause indicating the key(s).
# - Remember to use aliases to write more concise and precise syntax.
# - Finally, the GROUP BY and ORDER BY clauses indicate how to sort the results table.

# %%
# %%sql
#
# CREATE TABLE artist_genre AS
# SELECT g."Name" AS genre, ar."Name" AS artist_name, COUNT("Quantity") AS tracks_sold
# FROM "Genre" g
# INNER JOIN "Track" t USING ("GenreId")
# INNER JOIN "InvoiceLine" i USING ("TrackId")
# INNER JOIN "Album" al USING ("AlbumId")
# INNER JOIN "Artist" ar USING ("ArtistId")
# GROUP BY g."Name", ar."Name"
# ORDER BY COUNT("Quantity") DESC
# Out:
#  * postgresql://postgres:***@localhost/Chinook
# 194 rows affected.
# []

# %%
# Create a DataFrame.
q3 = pd.read_sql('SELECT * FROM artist_genre', engine)

# View the output.
q3
# Out:
#          genre                                        artist_name  tracks_sold
# 0        Metal                                          Metallica           91
# 1         Rock                                                 U2           91
# 2         Rock                                       Led Zeppelin           87
# 3        Metal                                        Iron Maiden           70
# 4         Rock                                        Iron Maiden           54
# ..         ...                                                ...          ...
# 189  Classical              Orchestra of The Age of Enlightenment            1
# 190  Classical  Academy of St. Martin in the Fields, John Birc...            1
# 191  Classical           Antal Doráti & London Symphony Orchestra            1
# 192  Classical             Berliner Philharmoniker & Hans Rosbaud            1
# 193  Classical                                       Julian Bream            1
#
# [194 rows x 3 columns]

# %% [markdown]
# #### Apply your learning
# Are you ready for a challenge? See if you can answer this problem on your own.
#
# Determine the most popular artist based on genre, tracks sold and customer country.

# %%
# %%sql
#
# SELECT g."Name" AS genre, ar."Name" AS artist_name, "Country", COUNT("Quantity") AS tracks_sold
# FROM "Genre" g
# INNER JOIN "Track" t USING ("GenreId")
# INNER JOIN "InvoiceLine" i USING ("TrackId")
# INNER JOIN "Album" al USING ("AlbumId")
# INNER JOIN "Artist" ar USING ("ArtistId")
# INNER JOIN "Invoice" i2 USING ("InvoiceId")
# INNER JOIN "Customer" c USING ("CustomerId")
# GROUP BY g."Name", ar."Name", "Country"
# ORDER BY COUNT("Quantity") DESC
# Out:
#  * postgresql://postgres:***@localhost/Chinook
# 801 rows affected.
# [('Metal', 'Metallica', 'USA', 27),
#  ('Rock', 'U2', 'USA', 23),
#  ('Latin', 'Os Paralamas Do Sucesso', 'Canada', 16),
#  ('Metal', 'Metallica', 'Canada', 15),
#  ('Metal', 'Iron Maiden', 'USA', 15),
#  ('Rock', 'Deep Purple', 'USA', 15),
#  ('Rock', 'Led Zeppelin', 'Canada', 14),
#  ('Rock', 'Iron Maiden', 'USA', 14),
#  ('Rock', 'Led Zeppelin', 'USA', 13),
#  ('Rock', 'Led Zeppelin', 'Germany', 12),
#  ('Latin', 'Tim Maia', 'USA', 12),
#  ('Latin', 'Caetano Veloso', 'USA', 12),
#  ('Latin', 'Os Paralamas Do Sucesso', 'Brazil', 11),
#  ('Rock', 'Creedence Clearwater Revival', 'France', 11),
#  ('Alternative & Punk', 'Green Day', 'USA', 11),
#  ('Rock', 'Pearl Jam', 'Brazil', 10),
#  ('Blues', 'Eric Clapton', 'USA', 10),
#  ('Rock', 'Led Zeppelin', 'France', 10),
#  ('Latin', 'Antônio Carlos Jobim', 'USA', 10),
#  ('Metal', 'Metallica', 'France', 10),
#  ('Latin', 'Chico Science & Nação Zumbi', 'Brazil', 9),
#  ('Alternative & Punk', 'R.E.M.', 'Canada', 9),
#  ('Rock', 'The Cult', 'USA', 9),
#  ('Rock', 'Led Zeppelin', 'Norway', 9),
#  ('Rock', 'Iron Maiden', 'Australia', 9),
#  ('TV Shows', 'The Office', 'USA', 9),
#  ('Rock', 'Queen', 'Canada', 9),
#  ('Rock', 'U2', 'Portugal', 9),
#  ('Metal', 'Metallica', 'United Kingdom', 9),
#  ('Rock', 'Kiss', 'Canada', 9),
#  ('Rock', 'U2', 'Austria', 9),
#  ('Metal', 'Metallica', 'Germany', 9),
#  ('R&B/Soul', 'Amy Winehouse', 'USA', 9),
#  ('Rock', 'Deep Purple', 'Germany', 9),
#  ('Rock', "Guns N' Roses", 'Brazil', 9),
#  ('Alternative & Punk', 'Faith No More', 'USA', 8),
#  ('Rock', 'The Rolling Stones', 'USA', 8),
#  ('Rock', 'U2', 'Canada', 8),
#  ('Metal', 'Iron Maiden', 'Portugal', 8),
#  ('Rock', "Guns N' Roses", 'USA', 8),
#  ('Rock', 'Van Halen', 'Germany', 8),
#  ('Comedy', 'The Office', 'USA', 8),
#  ('Rock', 'Van Halen', 'USA', 8),
#  ('Rock', 'Deep Purple', 'Brazil', 7),
#  ('Alternative & Punk', 'Faith No More', 'Belgium', 7),
#  ('Bossa Nova', 'Toquinho & Vinícius', 'Canada', 7),
#  ('Latin', 'Chico Buarque', 'France', 7),
#  ('Metal', 'Iron Maiden', 'United Kingdom', 7),
#  ('Rock', 'Creedence Clearwater Revival', 'Denmark', 7),
#  ('Rock', 'Soundgarden', 'USA', 7),
#  ('Rock', 'Led Zeppelin', 'United Kingdom', 7),
#  ('Rock', 'Deep Purple', 'India', 7),
#  ('Bossa Nova', 'Toquinho & Vinícius', 'USA', 7),
#  ('Latin', 'Lulu Santos', 'United Kingdom', 7),
#  ('Rock', 'U2', 'Brazil', 7),
#  ('TV Shows', 'Lost', 'Ireland', 7),
#  ('Blues', 'Eric Clapton', 'Germany', 6),
#  ('Alternative & Punk', 'Titãs', 'USA', 6),
#  ('Rock', 'Pearl Jam', 'Canada', 6),
#  ('Latin', 'Chico Science & Nação Zumbi', 'Canada', 6),
#  ('Rock', 'Led Zeppelin', 'Chile', 6),
#  ('Latin', 'Tim Maia', 'Brazil', 6),
#  ('Metal', 'Iron Maiden', 'Germany', 6),
#  ('Rock', 'U2', 'Ireland', 6),
#  ('Latin', 'Djavan', 'Germany', 6),
#  ('Latin', 'Various Artists', 'USA', 6),
#  ('Alternative & Punk', 'Faith No More', 'Germany', 6),
#  ('Metal', 'Iron Maiden', 'India', 6),
#  ('Rock', 'Van Halen', 'Finland', 6),
#  ('Metal', 'Judas Priest', 'Canada', 6),
#  ('Metal', 'Iron Maiden', 'Canada', 6),
#  ('Latin', 'Chico Science & Nação Zumbi', 'Ireland', 6),
#  ('Rock', 'U2', 'Poland', 6),
#  ('Rock', 'Foo Fighters', 'USA', 6),
#  ('Alternative & Punk', 'Body Count', 'France', 6),
#  ('Jazz', 'Spyro Gyra', 'USA', 6),
#  ('Metal', 'Metallica', 'Argentina', 6),
#  ('Jazz', 'Gene Krupa', 'India', 6),
#  ('Rock', 'Men At Work', 'Brazil', 6),
#  ('Metal', 'Metallica', 'Brazil', 6),
#  ('TV Shows', 'Lost', 'Czech Republic', 5),
#  ('Latin', 'Milton Nascimento', 'Canada', 5),
#  ('Rock', 'Pearl Jam', 'Spain', 5),
#  ('Rock', 'Queen', 'France', 5),
#  ('Alternative & Punk', 'Smashing Pumpkins', 'Canada', 5),
#  ('Latin', 'Chico Buarque', 'Brazil', 5),
#  ('Metal', 'Iron Maiden', 'Brazil', 5),
#  ('Rock', 'The Rolling Stones', 'Belgium', 5),
#  ('Rock', 'Iron Maiden', 'Portugal', 5),
#  ('Latin', 'Chico Buarque', 'USA', 5),
#  ('Alternative & Punk', 'R.E.M.', 'USA', 5),
#  ('Latin', 'Various Artists', 'France', 5),
#  ('Rock', 'Iron Maiden', 'Czech Republic', 5),
#  ('Latin', 'Cássia Eller', 'Poland', 5),
#  ('Metal', 'Iron Maiden', 'Australia', 5),
#  ('Rock', 'Queen', 'USA', 5),
#  ('Latin', 'Milton Nascimento', 'USA', 5),
#  ('Rock', 'The Rolling Stones', 'Italy', 5),
#  ('Rock', 'U2', 'Australia', 5),
#  ('Latin', 'Caetano Veloso', 'Czech Republic', 5),
#  ('Latin', 'Cássia Eller', 'Canada', 5),
#  ('Rock', 'U2', 'Czech Republic', 5),
#  ('Latin', 'Legião Urbana', 'Finland', 5),
#  ('Rock', 'The Who', 'Spain', 5),
#  ('Alternative & Punk', 'The Clash', 'USA', 5),
#  ('Alternative & Punk', 'Titãs', 'Canada', 5),
#  ('Rock', 'Led Zeppelin', 'Brazil', 5),
#  ('Latin', 'Os Paralamas Do Sucesso', 'USA', 5),
#  ('Blues', 'The Black Crowes', 'Brazil', 5),
#  ('Rock', 'Kiss', 'Finland', 5),
#  ('Metal', "Guns N' Roses", 'USA', 5),
#  ('Jazz', 'Miles Davis', 'France', 5),
#  ('Rock', 'U2', 'France', 5),
#  ('Latin', 'Gilberto Gil', 'USA', 5),
#  ('Latin', 'Cássia Eller', 'Norway', 5),
#  ('Alternative & Punk', 'Titãs', 'Sweden', 5),
#  ('Rock', 'Nirvana', 'Canada', 5),
#  ('Alternative & Punk', 'Titãs', 'Argentina', 5),
#  ('Reggae', 'Cidade Negra', 'United Kingdom', 5),
#  ('Rock', 'Red Hot Chili Peppers', 'France', 5),
#  ('Rock', 'R.E.M.', 'Brazil', 5),
#  ('Latin', 'Legião Urbana', 'USA', 4),
#  ('Rock', 'Led Zeppelin', 'Portugal', 4),
#  ('Rock', 'Van Halen', 'Czech Republic', 4),
#  ('Rock', 'Foo Fighters', 'Argentina', 4),
#  ('Heavy Metal', 'Iron Maiden', 'USA', 4),
#  ('Alternative & Punk', 'The Tea Party', 'Ireland', 4),
#  ('Metal', 'Godsmack', 'Germany', 4),
#  ('Alternative & Punk', 'Faith No More', 'Italy', 4),
#  ('Rock', 'Soundgarden', 'Brazil', 4),
#  ('Latin', 'Tim Maia', 'Argentina', 4),
#  ('Rock', 'AC/DC', 'Norway', 4),
#  ('Latin', 'Marisa Monte', 'United Kingdom', 4),
#  ('Rock', 'Iron Maiden', 'Germany', 4),
#  ('Jazz', 'Miles Davis', 'Canada', 4),
#  ('Rock', 'Creedence Clearwater Revival', 'Canada', 4),
#  ('Alternative & Punk', 'Titãs', 'Italy', 4),
#  ('Rock', 'Kiss', 'Brazil', 4),
#  ('Rock', 'Red Hot Chili Peppers', 'Netherlands', 4),
#  ('Drama', 'Lost', 'USA', 4),
#  ('Rock', 'Iron Maiden', 'France', 4),
#  ('Metal', 'Mötley Crüe', 'Canada', 4),
#  ('Reggae', 'Cidade Negra', 'USA', 4),
#  ('Sci Fi & Fantasy', 'Battlestar Galactica (Classic)', 'USA', 4),
#  ('Pop', 'Amy Winehouse', 'USA', 4),
#  ('Jazz', 'Miles Davis', 'USA', 4),
#  ('Rock', 'Queen', 'Spain', 4),
#  ('TV Shows', 'Lost', 'Austria', 4),
#  ('R&B/Soul', 'James Brown', 'India', 4),
#  ('Blues', 'The Black Crowes', 'Germany', 4),
#  ('Rock', 'The Who', 'Austria', 4),
#  ('Latin', 'Caetano Veloso', 'Sweden', 4),
#  ('Pop', 'U2', 'Portugal', 4),
#  ('Rock', 'The Police', 'USA', 4),
#  ('Alternative & Punk', 'Smashing Pumpkins', 'Belgium', 4),
#  ('Rock', 'Deep Purple', 'Poland', 4),
#  ('Sci Fi & Fantasy', 'Battlestar Galactica (Classic)', 'Finland', 4),
#  ('Rock', 'Queen', 'Germany', 4),
#  ('Pop', 'U2', 'Czech Republic', 4),
#  ('Rock', 'Alanis Morissette', 'Canada', 4),
#  ('Alternative & Punk', 'Smashing Pumpkins', 'Poland', 4),
#  ('Latin', 'Eric Clapton', 'USA', 4),
#  ('Alternative & Punk', 'Green Day', 'United Kingdom', 4),
#  ('Jazz', 'Spyro Gyra', 'Canada', 4),
#  ('Latin', 'Legião Urbana', 'United Kingdom', 4),
#  ('TV Shows', 'The Office', 'Hungary', 4),
#  ('Rock', 'Nirvana', 'Brazil', 4),
#  ('Metal', 'Black Label Society', 'USA', 4),
#  ('Metal', 'Iron Maiden', 'Czech Republic', 4),
#  ('Blues', 'Stevie Ray Vaughan & Double Trouble', 'Netherlands', 4),
#  ('Hip Hop/Rap', 'Planet Hemp', 'USA', 4),
#  ('Rock', 'Ozzy Osbourne', 'Portugal', 4),
#  ('Rock', 'Aerosmith', 'Belgium', 4),
#  ('TV Shows', 'Lost', 'USA', 4),
#  ('Rock', 'Creedence Clearwater Revival', 'India', 4),
#  ('Rock', 'Raul Seixas', 'Portugal', 4),
#  ('Blues', 'Eric Clapton', 'Italy', 4),
#  ('Rock', 'U2', 'Hungary', 4),
#  ('Metal', 'System Of A Down', 'Denmark', 4),
#  ('Rock', 'Kiss', 'Germany', 4),
#  ('Alternative & Punk', 'The Tea Party', 'Belgium', 3),
#  ('Latin', 'Olodum', 'United Kingdom', 3),
#  ('Latin', 'Gonzaguinha', 'Brazil', 3),
#  ('Jazz', 'Gene Krupa', 'France', 3),
#  ('Latin', 'Falamansa', 'Netherlands', 3),
#  ('Rock', 'Page & Plant', 'Australia', 3),
#  ('Alternative & Punk', 'Green Day', 'Spain', 3),
#  ('Alternative & Punk', 'Os Mutantes', 'Canada', 3),
#  ('Rock', 'Queen', 'Brazil', 3),
#  ('Jazz', 'Incognito', 'USA', 3),
#  ('Rock', 'AC/DC', 'Italy', 3),
#  ('Latin', 'Jorge Ben', 'Canada', 3),
#  ('Rock', 'AC/DC', 'Brazil', 3),
#  ('Latin', 'Cássia Eller', 'USA', 3),
#  ('Rock', 'Raul Seixas', 'USA', 3),
#  ('Rock', 'Nirvana', 'Sweden', 3),
#  ('Latin', 'Milton Nascimento', 'Sweden', 3),
#  ('Rock', 'Skank', 'Canada', 3),
#  ('Metal', 'Black Sabbath', 'Germany', 3),
#  ('Rock', 'Jimi Hendrix', 'Canada', 3),
#  ('Rock', 'David Coverdale', 'USA', 3),
#  ('Heavy Metal', 'Iron Maiden', 'Australia', 3),
#  ('Rock', 'Creedence Clearwater Revival', 'USA', 3),
#  ('Latin', 'Os Paralamas Do Sucesso', 'Portugal', 3),
#  ('Rock', 'O Terço', 'Spain', 3),
#  ('Rock', 'Foo Fighters', 'Netherlands', 3),
#  ('Easy Listening', 'Frank Sinatra', 'Chile', 3),
#  ('World', 'Mônica Marianno', 'Canada', 3),
#  ('Alternative & Punk', 'Green Day', 'Czech Republic', 3),
#  ('Latin', 'Lulu Santos', 'Canada', 3),
#  ('Latin', 'Falamansa', 'USA', 3),
#  ('Alternative & Punk', 'R.E.M.', 'France', 3),
#  ('Easy Listening', 'Frank Sinatra', 'USA', 3),
#  ('Soundtrack', 'Passengers', 'France', 3),
#  ('Latin', 'Ed Motta', 'France', 3),
#  ('Drama', 'Lost', 'Czech Republic', 3),
#  ('Jazz', 'Miles Davis', 'India', 3),
#  ('Rock', 'Iron Maiden', 'Canada', 3),
#  ('Latin', 'Djavan', 'India', 3),
#  ('Hip Hop/Rap', 'House Of Pain', 'Canada', 3),
#  ('Drama', 'Heroes', 'Czech Republic', 3),
#  ('Rock', 'Audioslave', 'Canada', 3),
#  ('Sci Fi & Fantasy', 'Battlestar Galactica (Classic)', 'Netherlands', 3),
#  ('Hip Hop/Rap', 'House Of Pain', 'United Kingdom', 3),
#  ('R&B/Soul', 'Marvin Gaye', 'Brazil', 3),
#  ('Rock', "Guns N' Roses", 'Ireland', 3),
#  ('Latin', 'Gilberto Gil', 'Brazil', 3),
#  ('Alternative & Punk', 'Titãs', 'France', 3),
#  ('Alternative & Punk', 'Green Day', 'France', 3),
#  ('Metal', 'Ozzy Osbourne', 'Australia', 3),
#  ('Latin', 'Elis Regina', 'United Kingdom', 3),
#  ('Latin', 'Various Artists', 'Portugal', 3),
#  ('Heavy Metal', 'Iron Maiden', 'Germany', 3),
#  ('Jazz', 'Gene Krupa', 'United Kingdom', 3),
#  ('Alternative & Punk', 'Faith No More', 'France', 3),
#  ('Alternative & Punk', 'Audioslave', 'USA', 3),
#  ('R&B/Soul', 'James Brown', 'USA', 3),
#  ('Alternative & Punk', 'The Clash', 'India', 3),
#  ('Alternative & Punk', 'The Tea Party', 'USA', 3),
#  ('Rock', 'Aerosmith', 'United Kingdom', 3),
#  ('Latin', 'Eric Clapton', 'Canada', 3),
#  ('Reggae', 'UB40', 'Canada', 3),
#  ('Latin', 'Elis Regina', 'France', 3),
#  ('Alternative & Punk', 'The Tea Party', 'France', 3),
#  ('Latin', 'Djavan', 'Canada', 3),
#  ('Rock', 'Faith No More', 'France', 3),
#  ('Rock', 'Foo Fighters', 'Germany', 3),
#  ('R&B/Soul', 'Amy Winehouse', 'Austria', 3),
#  ('Rock', 'Stone Temple Pilots', 'United Kingdom', 3),
#  ('Reggae', 'Cidade Negra', 'Brazil', 3),
#  ('Alternative & Punk', 'R.E.M. Feat. Kate Pearson', 'Canada', 3),
#  ('Reggae', 'Lenny Kravitz', 'Brazil', 3),
#  ('Jazz', 'Spyro Gyra', 'Czech Republic', 3),
#  ('Blues', 'Buddy Guy', 'Germany', 3),
#  ('Alternative & Punk', 'Red Hot Chili Peppers', 'France', 3),
#  ('Rock', 'Ozzy Osbourne', 'Denmark', 3),
#  ('Drama', 'Heroes', 'Chile', 3),
#  ('World', 'João Suplicy', 'Canada', 3),
#  ('Latin', 'Chico Buarque', 'Germany', 3),
#  ('Metal', 'Bruce Dickinson', 'Hungary', 3),
#  ('Rock', 'Red Hot Chili Peppers', 'USA', 3),
#  ('Reggae', 'Cidade Negra', 'Canada', 3),
#  ('Latin', 'Os Paralamas Do Sucesso', 'United Kingdom', 3),
#  ('Rock', 'The Who', 'USA', 3),
#  ('Latin', 'Zeca Pagodinho', 'USA', 3),
#  ('Pop', 'U2', 'Netherlands', 3),
#  ('Rock', 'R.E.M.', 'United Kingdom', 3),
#  ('Blues', 'The Black Crowes', 'India', 3),
#  ('Latin', 'Jota Quest', 'Canada', 3),
#  ('Rock', 'Ozzy Osbourne', 'Sweden', 3),
#  ('Pop', 'U2', 'Denmark', 3),
#  ('Alternative & Punk', 'Smashing Pumpkins', 'Denmark', 3),
#  ('Rock', 'Skank', 'Netherlands', 3),
#  ('Alternative & Punk', 'Green Day', 'Canada', 3),
#  ('Rock', 'Lenny Kravitz', 'Finland', 3),
#  ('Alternative & Punk', 'Titãs', 'Germany', 3),
#  ('Rock', 'Def Leppard', 'USA', 3),
#  ('Rock', 'Red Hot Chili Peppers', 'Denmark', 3),
#  ('Latin', 'Chico Buarque', 'Sweden', 3),
#  ('Jazz', 'Antônio Carlos Jobim', 'Canada', 3),
#  ('Rock', 'Pearl Jam', 'Germany', 3),
#  ('Metal', "Guns N' Roses", 'Ireland', 3),
#  ('Latin', 'Legião Urbana', 'Brazil', 3),
#  ('Rock', 'AC/DC', 'Canada', 3),
#  ('Latin', 'Djavan', 'USA', 3),
#  ('Latin', 'Lulu Santos', 'Brazil', 3),
#  ('Rock And Roll', 'BackBeat', 'USA', 3),
#  ('Metal', 'Black Sabbath', 'France', 3),
#  ('Drama', 'Lost', 'France', 3),
#  ('Electronica/Dance', 'O Rappa', 'Canada', 3),
#  ('Rock', 'Santana', 'France', 3),
#  ('Rock', 'The Cult', 'Italy', 3),
#  ('R&B/Soul', 'James Brown', 'Hungary', 3),
#  ('Metal', 'Iron Maiden', 'Austria', 3),
#  ('Jazz', 'Billy Cobham', 'USA', 2),
#  ('Latin', 'Eric Clapton', 'Portugal', 2),
#  ('Metal', 'System Of A Down', 'United Kingdom', 2),
#  ('Rock', 'The Who', 'Canada', 2),
#  ('Alternative & Punk', 'R.E.M.', 'India', 2),
#  ('Rock', 'Lenny Kravitz', 'Canada', 2),
#  ('Latin', 'Gilberto Gil', 'Canada', 2),
#  ('Rock', 'The Who', 'Czech Republic', 2),
#  ('Sci Fi & Fantasy', 'Battlestar Galactica (Classic)', 'France', 2),
#  ('Rock', 'Alice In Chains', 'United Kingdom', 2),
#  ('Alternative & Punk', 'JET', 'Canada', 2),
#  ('Latin', 'Funk Como Le Gusta', 'Chile', 2),
#  ('Rock', 'Kiss', 'United Kingdom', 2),
#  ('Rock', 'Van Halen', 'Australia', 2),
#  ('Rock', 'Alice In Chains', 'Canada', 2),
#  ('Metal', 'Motörhead', 'Canada', 2),
#  ('Rock', 'Santana', 'India', 2),
#  ('Rock', 'Red Hot Chili Peppers', 'Canada', 2),
#  ('Rock', "Guns N' Roses", 'France', 2),
#  ('Rock', 'U2', 'Germany', 2),
#  ('Latin', 'Antônio Carlos Jobim', 'Germany', 2),
#  ('Alternative', 'Audioslave', 'France', 2),
#  ('Latin', 'Elis Regina', 'Australia', 2),
#  ('R&B/Soul', 'Marvin Gaye', 'United Kingdom', 2),
#  ('Metal', 'Bruce Dickinson', 'Chile', 2),
#  ('Pop', 'Various Artists', 'France', 2),
#  ('Metal', 'Apocalyptica', 'Canada', 2),
#  ('Metal', 'Ozzy Osbourne', 'Brazil', 2),
#  ('R&B/Soul', 'Jamiroquai', 'Portugal', 2),
#  ('Metal', 'System Of A Down', 'Austria', 2),
#  ('Blues', 'Eric Clapton', 'France', 2),
#  ('Metal', 'Metallica', 'Spain', 2),
#  ('Latin', 'Gilberto Gil', 'Chile', 2),
#  ('Rock', 'AC/DC', 'Belgium', 2),
#  ('Jazz', 'Incognito', 'Ireland', 2),
#  ('Alternative & Punk', 'Smashing Pumpkins', 'USA', 2),
#  ('Rock', 'Raul Seixas', 'India', 2),
#  ('Alternative', 'Audioslave', 'USA', 2),
#  ('Jazz', 'Incognito', 'Austria', 2),
#  ('Alternative & Punk', 'R.E.M. Feat. Kate Pearson', 'Poland', 2),
#  ('Latin', 'Jota Quest', 'United Kingdom', 2),
#  ('Blues', 'Eric Clapton', 'Chile', 2),
#  ('Drama', 'Heroes', 'USA', 2),
#  ('Latin', 'Zeca Pagodinho', 'Finland', 2),
#  ('Rock', 'David Coverdale', 'Spain', 2),
#  ('Latin', 'Chico Science & Nação Zumbi', 'United Kingdom', 2),
#  ('Rock', 'O Terço', 'Canada', 2),
#  ('Rock', "Guns N' Roses", 'Canada', 2),
#  ('Rock', 'Pearl Jam', 'France', 2),
#  ('Rock And Roll', 'BackBeat', 'Canada', 2),
#  ('Rock', 'Creedence Clearwater Revival', 'Australia', 2),
#  ('Rock', 'Def Leppard', 'Germany', 2),
#  ('Alternative & Punk', 'JET', 'United Kingdom', 2),
#  ('Latin', 'Funk Como Le Gusta', 'Germany', 2),
#  ('Alternative & Punk', 'Titãs', 'Hungary', 2),
#  ('Rock', 'Velvet Revolver', 'Czech Republic', 2),
#  ('Rock', 'R.E.M.', 'France', 2),
#  ('Soundtrack', 'Various Artists', 'Brazil', 2),
#  ('Soundtrack', 'Passengers', 'Brazil', 2),
#  ('Latin', 'Chico Buarque', 'India', 2),
#  ('Rock', 'Pink Floyd', 'Brazil', 2),
#  ('Blues', 'Stevie Ray Vaughan & Double Trouble', 'Canada', 2),
#  ('Rock', 'Soundgarden', 'Poland', 2),
#  ('Rock', 'Faith No More', 'USA', 2),
#  ('Latin', 'Os Paralamas Do Sucesso', 'Poland', 2),
#  ('Rock', 'The Doors', 'USA', 2),
#  ('Hip Hop/Rap', 'Planet Hemp', 'Brazil', 2),
#  ('Alternative & Punk', 'Pearl Jam', 'Germany', 2),
#  ('Latin', 'Marcos Valle', 'Germany', 2),
#  ('Alternative & Punk', 'Faith No More', 'Portugal', 2),
#  ('Blues', 'Buddy Guy', 'Hungary', 2),
#  ('Jazz', 'Antônio Carlos Jobim', 'USA', 2),
#  ('Alternative & Punk', 'Smashing Pumpkins', 'Czech Republic', 2),
#  ('TV Shows', 'Heroes', 'Germany', 2),
#  ('Latin', 'Marisa Monte', 'Canada', 2),
#  ('Jazz', 'Incognito', 'Portugal', 2),
#  ('Alternative & Punk', 'The Tea Party', 'Finland', 2),
#  ('Latin', 'Eric Clapton', 'Germany', 2),
#  ('Electronica/Dance', 'O Rappa', 'France', 2),
#  ('Alternative & Punk', 'Smashing Pumpkins', 'Norway', 2),
#  ('Jazz', 'Dennis Chambers', 'USA', 2),
#  ('Alternative & Punk', 'Raimundos', 'India', 2),
#  ('Rock', 'Led Zeppelin', 'Sweden', 2),
#  ('Alternative & Punk', 'Smashing Pumpkins', 'Brazil', 2),
#  ('Reggae', 'UB40', 'USA', 2),
#  ('Metal', 'Lenny Kravitz', 'Czech Republic', 2),
#  ('Alternative & Punk', 'Raimundos', 'France', 2),
#  ('Rock', 'Jamiroquai', 'Hungary', 2),
#  ('Pop', 'Various Artists', 'Brazil', 2),
#  ('Latin', 'Funk Como Le Gusta', 'USA', 2),
#  ('R&B/Soul', 'Jamiroquai', 'Hungary', 2),
#  ('Soundtrack', 'Various Artists', 'France', 2),
#  ('Rock', 'David Coverdale', 'Brazil', 2),
#  ('R&B/Soul', 'Jamiroquai', 'Czech Republic', 2),
#  ('Metal', 'Black Label Society', 'France', 2),
#  ('Latin', 'Os Paralamas Do Sucesso', 'Denmark', 2),
#  ('Rock', "Paul D'Ianno", 'Germany', 2),
#  ('Rock', 'Santana', 'Canada', 2),
#  ('Latin', 'Antônio Carlos Jobim', 'France', 2),
#  ('Rock', 'Stone Temple Pilots', 'USA', 2),
#  ('R&B/Soul', 'Marvin Gaye', 'Belgium', 2),
#  ('Metal', 'Bruce Dickinson', 'Canada', 2),
#  ('Rock', 'Aerosmith', 'Canada', 2),
#  ('Latin', 'Marcos Valle', 'France', 2),
#  ('Alternative & Punk', 'Body Count', 'Canada', 2),
#  ('Alternative & Punk', 'Green Day', 'Chile', 2),
#  ('Blues', 'The Black Crowes', 'USA', 2),
#  ('Latin', 'Zeca Pagodinho', 'Hungary', 2),
#  ('Latin', 'Chico Buarque', 'Canada', 2),
#  ('Latin', 'Cláudio Zoli', 'United Kingdom', 2),
#  ('Blues', 'Eric Clapton', 'Canada', 2),
#  ('Alternative & Punk', 'R.E.M.', 'Brazil', 2),
#  ('Latin', 'Funk Como Le Gusta', 'Argentina', 2),
#  ('Rock', 'Skank', 'Poland', 2),
#  ('Easy Listening', 'Frank Sinatra', 'Germany', 2),
#  ('Metal', 'System Of A Down', 'USA', 2),
#  ('Alternative & Punk', 'Os Mutantes', 'France', 2),
#  ('Metal', 'Metallica', 'Denmark', 2),
#  ('Latin', 'Eric Clapton', 'Chile', 2),
#  ('Rock', 'Accept', 'Germany', 2),
#  ('Rock', 'Stone Temple Pilots', 'Czech Republic', 2),
#  ('Rock', "Guns N' Roses", 'Argentina', 2),
#  ('Metal', 'Motörhead', 'Sweden', 2),
#  ('Rock', 'The Cult', 'Belgium', 2),
#  ('Alternative & Punk', 'Raimundos', 'Portugal', 2),
#  ('Latin', 'Zeca Pagodinho', 'Czech Republic', 2),
#  ('Alternative & Punk', 'Red Hot Chili Peppers', 'USA', 2),
#  ('Latin', 'Marcos Valle', 'USA', 2),
#  ('World', 'Mônica Marianno', 'Brazil', 2),
#  ('Pop', 'U2', 'United Kingdom', 2),
#  ('Rock', 'R.E.M.', 'Czech Republic', 2),
#  ('Rock', 'Kiss', 'Argentina', 2),
#  ('Reggae', 'UB40', 'Australia', 2),
#  ('Jazz', 'Gene Krupa', 'USA', 2),
#  ('Rock', 'Iron Maiden', 'Austria', 2),
#  ('Soundtrack', 'Gilberto Gil', 'Germany', 2),
#  ('Latin', 'Cássia Eller', 'Brazil', 2),
#  ('Alternative & Punk', 'R.E.M. Feat. Kate Pearson', 'France', 2),
#  ('Alternative & Punk', 'Pearl Jam', 'Canada', 2),
#  ('Latin', 'Gonzaguinha', 'Spain', 2),
#  ('Science Fiction', 'Battlestar Galactica', 'Germany', 2),
#  ('Classical', 'Berliner Philharmoniker & Herbert Von Karajan', 'Austria', 2),
#  ('Rock', 'Joe Satriani', 'Canada', 2),
#  ('Rock', 'O Terço', 'Sweden', 2),
#  ('Rock', 'Marillion', 'Canada', 2),
#  ('Latin', 'Ed Motta', 'USA', 2),
#  ('Electronica/Dance', 'O Rappa', 'Norway', 2),
#  ('Metal', 'Black Label Society', 'Canada', 2),
#  ('Rock', 'Led Zeppelin', 'Poland', 2),
#  ('Latin', 'Elis Regina', 'India', 2),
#  ('Rock', 'R.E.M.', 'Belgium', 2),
#  ('Rock', 'The Who', 'Belgium', 2),
#  ('Rock', 'O Terço', 'Ireland', 2),
#  ('Heavy Metal', 'Iron Maiden', 'Portugal', 2),
#  ('Hip Hop/Rap', 'Planet Hemp', 'Canada', 2),
#  ('Rock', 'Page & Plant', 'USA', 2),
#  ('Latin', 'Jorge Ben', 'Portugal', 2),
#  ('Rock', 'Iron Maiden', 'India', 2),
#  ('Metal', 'Iron Maiden', 'France', 2),
#  ('Drama', 'Lost', 'Canada', 2),
#  ('Electronica/Dance', 'Jamiroquai', 'Czech Republic', 2),
#  ('Rock', 'Rush', 'Denmark', 2),
#  ('Latin', 'Marisa Monte', 'Brazil', 2),
#  ('Rock', 'Alanis Morissette', 'United Kingdom', 2),
#  ('Rock', 'The Cult', 'India', 2),
#  ('Latin', 'Vinícius De Moraes', 'Finland', 2),
#  ('Metal', 'Iron Maiden', 'Sweden', 2),
#  ('Latin', 'Olodum', 'Brazil', 2),
#  ('Rock', 'Soundgarden', 'Canada', 2),
#  ('Rock', 'Alanis Morissette', 'USA', 2),
#  ('Sci Fi & Fantasy', 'Battlestar Galactica (Classic)', 'Brazil', 2),
#  ('Latin', 'Elis Regina', 'Chile', 2),
#  ('Jazz', 'Gene Krupa', 'Argentina', 2),
#  ('Latin', 'Milton Nascimento', 'Brazil', 2),
#  ('Rock', 'Lenny Kravitz', 'Brazil', 2),
#  ('Rock', 'Lenny Kravitz', 'Poland', 2),
#  ('Rock', 'Scorpions', 'United Kingdom', 2),
#  ('Rock', 'Def Leppard', 'India', 2),
#  ('Metal', 'Godsmack', 'USA', 2),
#  ('Alternative', 'Temple of the Dog', 'USA', 2),
#  ('Rock', 'Page & Plant', 'France', 2),
#  ('Rock', 'Queen', 'Finland', 2),
#  ('Jazz', 'Spyro Gyra', 'Finland', 2),
#  ('Science Fiction', 'Battlestar Galactica', 'Chile', 2),
#  ('Metal', 'Judas Priest', 'United Kingdom', 2),
#  ('Rock', 'Iron Maiden', 'Spain', 2),
#  ('Metal', 'System Of A Down', 'Germany', 2),
#  ('Rock', 'Creedence Clearwater Revival', 'Germany', 2),
#  ('Rock', 'Queen', 'Italy', 2),
#  ('Alternative & Punk', 'R.E.M.', 'United Kingdom', 2),
#  ('Metal', 'Metallica', 'Netherlands', 2),
#  ('Hip Hop/Rap', 'House Of Pain', 'France', 2),
#  ('Latin', 'Chico Science & Nação Zumbi', 'Sweden', 2),
#  ('R&B/Soul', 'James Brown', 'Canada', 2),
#  ('Rock', 'Lenny Kravitz', 'Denmark', 2),
#  ('Rock', 'Faith No More', 'Belgium', 2),
#  ('Rock', 'O Terço', 'Netherlands', 2),
#  ('Metal', 'Bruce Dickinson', 'India', 2),
#  ('Classical', 'Michael Tilson Thomas & San Francisco Symphony', 'Canada', 2),
#  ('Rock', 'Marillion', 'United Kingdom', 2),
#  ('Metal', "Guns N' Roses", 'Austria', 2),
#  ('Rock', 'Jimi Hendrix', 'United Kingdom', 2),
#  ('Reggae', 'Lenny Kravitz', 'Spain', 2),
#  ('Metal', 'Black Sabbath', 'USA', 2),
#  ('Rock', 'Santana', 'Netherlands', 2),
#  ('Rock', 'Kiss', 'India', 2),
#  ('Alternative & Punk', 'JET', 'Czech Republic', 2),
#  ('Rock', 'Scorpions', 'Canada', 2),
#  ('Jazz', 'Spyro Gyra', 'Spain', 2),
#  ('Rock', 'U2', 'Norway', 2),
#  ('Alternative & Punk', 'Red Hot Chili Peppers', 'Netherlands', 2),
#  ('Rock', 'Skank', 'Denmark', 2),
#  ('Alternative', 'Chris Cornell', 'Norway', 2),
#  ('TV Shows', 'The Office', 'Czech Republic', 2),
#  ('Alternative & Punk', 'Red Hot Chili Peppers', 'India', 2),
#  ('Soundtrack', 'Passengers', 'USA', 2),
#  ('Soundtrack', 'Passengers', 'Germany', 2),
#  ('Alternative & Punk', 'Foo Fighters', 'Netherlands', 2),
#  ('World', 'João Suplicy', 'Portugal', 2),
#  ('Easy Listening', 'Frank Sinatra', 'Argentina', 2),
#  ('Rock', 'Ozzy Osbourne', 'United Kingdom', 2),
#  ('Latin', 'Gonzaguinha', 'France', 2),
#  ('Alternative & Punk', 'The Tea Party', 'Italy', 2),
#  ('Rock', 'Creedence Clearwater Revival', 'Chile', 2),
#  ('Latin', 'Os Paralamas Do Sucesso', 'Italy', 2),
#  ('Latin', 'Olodum', 'Austria', 2),
#  ('Rock', 'The Police', 'Italy', 2),
#  ('Rock', 'Jimi Hendrix', 'Portugal', 2),
#  ('Alternative & Punk', 'Green Day', 'Argentina', 2),
#  ('Latin', 'Falamansa', 'Argentina', 2),
#  ('Rock', 'Jamiroquai', 'Czech Republic', 2),
#  ('R&B/Soul', 'Marvin Gaye', 'Canada', 2),
#  ('Latin', 'Djavan', 'Portugal', 2),
#  ('Rock', 'Alice In Chains', 'France', 2),
#  ('Metal', 'Lenny Kravitz', 'Hungary', 2),
#  ('Metal', 'Mötley Crüe', 'Sweden', 2),
#  ('Rock', 'Queen', 'Hungary', 2),
#  ('TV Shows', 'Lost', 'Chile', 2),
#  ('Alternative & Punk', 'Body Count', 'USA', 2),
#  ('Drama', 'Lost', 'Norway', 2),
#  ('Rock', 'Audioslave', 'France', 2),
#  ('Metal', 'Ozzy Osbourne', 'USA', 2),
#  ('Latin', 'Vinícius De Moraes', 'USA', 2),
#  ('Latin', 'Gonzaguinha', 'Canada', 2),
#  ('Metal', 'Lenny Kravitz', 'Finland', 2),
#  ('Jazz', 'Billy Cobham', 'France', 1),
#  ('Metal', 'Mötley Crüe', 'Brazil', 1),
#  ('Rock', 'Terry Bozzio, Tony Levin & Steve Stevens', 'India', 1),
#  ('Metal', 'Iron Maiden', 'Spain', 1),
#  ('Rock', 'Men At Work', 'United Kingdom', 1),
#  ('Rock', "Paul D'Ianno", 'Brazil', 1),
#  ('Alternative', 'Temple of the Dog', 'France', 1),
#  ('Pop', 'Amy Winehouse', 'Austria', 1),
#  ('Rock', 'Terry Bozzio, Tony Levin & Steve Stevens', 'Brazil', 1),
#  ('Latin', 'Various Artists', 'Denmark', 1),
#  ('Rock', 'Frank Zappa & Captain Beefheart', 'Brazil', 1),
#  ('TV Shows', 'Lost', 'France', 1),
#  ('Rock', 'The Posies', 'France', 1),
#  ('Rock', 'Joe Satriani', 'Portugal', 1),
#  ('Soundtrack', 'Gilberto Gil', 'USA', 1),
#  ('Latin', 'Djavan', 'France', 1),
#  ('Reggae', 'UB40', 'Finland', 1),
#  ('Rock', 'Scorpions', 'Portugal', 1),
#  ('Latin', 'Cláudio Zoli', 'USA', 1),
#  ('Classical', 'Royal Philharmonic Orchestra & Sir Thomas Beecham', 'Norway', 1),
#  ('Rock', 'Terry Bozzio, Tony Levin & Steve Stevens', 'Germany', 1),
#  ('Rock', 'Aerosmith', 'USA', 1),
#  ('Rock', 'Terry Bozzio, Tony Levin & Steve Stevens', 'USA', 1),
#  ('Rock', 'Iron Maiden', 'Ireland', 1),
#  ('Alternative & Punk', 'R.E.M. Feat. Kate Pearson', 'United Kingdom', 1),
#  ('Metal', 'Black Sabbath', 'Canada', 1),
#  ('Rock', 'Audioslave', 'USA', 1),
#  ('Rock', 'Faith No More', 'Argentina', 1),
#  ('Alternative & Punk', 'Red Hot Chili Peppers', 'Denmark', 1),
#  ('R&B/Soul', 'Marvin Gaye', 'Austria', 1),
#  ('Rock', 'Rush', 'Poland', 1),
#  ('Rock', 'O Terço', 'Brazil', 1),
#  ('Drama', 'Heroes', 'Hungary', 1),
#  ('Latin', 'Various Artists', 'India', 1),
#  ('Rock', 'Lenny Kravitz', 'Netherlands', 1),
#  ('Blues', 'Buddy Guy', 'USA', 1),
#  ('Metal', 'Lenny Kravitz', 'USA', 1),
#  ('Soundtrack', 'Various Artists', 'USA', 1),
#  ('Metal', 'Ozzy Osbourne', 'Portugal', 1),
#  ('Sci Fi & Fantasy', 'Battlestar Galactica (Classic)', 'Portugal', 1),
#  ('Rock', 'Kiss', 'Australia', 1),
#  ('Rock', 'Terry Bozzio, Tony Levin & Steve Stevens', 'United Kingdom', 1),
#  ('Rock', 'Faith No More', 'Italy', 1),
#  ('TV Shows', 'Battlestar Galactica', 'Czech Republic', 1),
#  ('Rock', 'Ozzy Osbourne', 'USA', 1),
#  ('Rock', 'Foo Fighters', 'Chile', 1),
#  ('Rock', 'O Terço', 'Hungary', 1),
#  ('Rock', 'Rush', 'Netherlands', 1),
#  ('Alternative & Punk', 'Pearl Jam', 'Spain', 1),
#  ('Metal', 'Apocalyptica', 'France', 1),
#  ('Alternative & Punk', 'Faith No More', 'Argentina', 1),
#  ('Latin', 'Various Artists', 'Canada', 1),
#  ('Reggae', 'Lenny Kravitz', 'Canada', 1),
#  ('Classical', 'Felix Schmidt, London Symphony Orchestra & Rafael Frühbeck de Burgos', 'Canada', 1),
#  ('Rock', 'Creedence Clearwater Revival', 'Norway', 1),
#  ('World', 'Habib Koité and Bamada', 'Norway', 1),
#  ('Latin', 'Antônio Carlos Jobim', 'Canada', 1),
#  ('Jazz', 'Dennis Chambers', 'India', 1),
#  ('Science Fiction', 'Battlestar Galactica', 'Czech Republic', 1),
#  ('Classical', 'Antal Doráti & London Symphony Orchestra', 'Canada', 1),
#  ('Rock', 'The Doors', 'Belgium', 1),
#  ('Rock', "Paul D'Ianno", 'Canada', 1),
#  ('Alternative & Punk', 'Audioslave', 'Canada', 1),
#  ('Classical', 'Berliner Philharmoniker & Hans Rosbaud', 'Brazil', 1),
#  ('Comedy', 'The Office', 'Hungary', 1),
#  ('Classical', 'Yehudi Menuhin', 'France', 1),
#  ('Sci Fi & Fantasy', 'Battlestar Galactica', 'Chile', 1),
#  ('Rock', 'Deep Purple', 'Canada', 1),
#  ('Metal', 'Judas Priest', 'USA', 1),
#  ('Rock', 'The Doors', 'Italy', 1),
#  ('Latin', 'Gilberto Gil', 'Germany', 1),
#  ('Rock', 'Marillion', 'Brazil', 1),
#  ('Latin', 'Jorge Ben', 'United Kingdom', 1),
#  ('Classical', 'Sir Georg Solti & Wiener Philharmoniker', 'France', 1),
#  ('Latin', 'Tim Maia', 'Canada', 1),
#  ('Latin', 'Legião Urbana', 'Canada', 1),
#  ('Metal', 'Ozzy Osbourne', 'Sweden', 1),
#  ('Latin', 'Elis Regina', 'USA', 1),
#  ('Metal', 'Bruce Dickinson', 'Argentina', 1),
#  ('Rock', 'Raul Seixas', 'Netherlands', 1),
#  ('Science Fiction', 'Battlestar Galactica', 'USA', 1),
#  ('Latin', 'Cássia Eller', 'Denmark', 1),
#  ('Blues', 'Stevie Ray Vaughan & Double Trouble', 'USA', 1),
#  ('Metal', 'Motörhead', 'USA', 1),
#  ('Classical', 'Academy of St. Martin in the Fields & Sir Neville Marriner', 'Brazil', 1),
#  ('TV Shows', 'Aquaman', 'Canada', 1),
#  ('Rock', 'Accept', 'Italy', 1),
#  ('Classical', 'Michele Campanella', 'Italy', 1),
#  ('Rock', 'Santana', 'USA', 1),
#  ('Alternative & Punk', 'Faith No More', 'Netherlands', 1),
#  ('Jazz', 'Gene Krupa', 'Canada', 1),
#  ('Rock', 'Stone Temple Pilots', 'Germany', 1),
#  ('Alternative', 'Calexico', 'Germany', 1),
#  ('Rock', 'The Who', 'Germany', 1),
#  ('Rock', 'Iron Maiden', 'United Kingdom', 1),
#  ('Rock', 'Velvet Revolver', 'Germany', 1),
#  ('Rock', 'Santana', 'Denmark', 1),
#  ('Classical', 'Julian Bream', 'France', 1),
#  ('Drama', 'Lost', 'Ireland', 1),
#  ('Jazz', 'Spyro Gyra', 'Ireland', 1),
#  ('Classical', 'Academy of St. Martin in the Fields, John Birch, Sir Neville Marriner & Sylvia McNair', 'USA', 1),
#  ('Rock', 'Alice In Chains', 'USA', 1),
#  ('Rock', 'Accept', 'Brazil', 1),
#  ('Pop', 'Various Artists', 'Germany', 1),
#  ('Rock', 'Stone Temple Pilots', 'Norway', 1),
#  ('Classical', 'Chicago Symphony Orchestra & Fritz Reiner', 'Chile', 1),
#  ('Soundtrack', 'Various Artists', 'Germany', 1),
#  ('Metal', 'Godsmack', 'Chile', 1),
#  ('Alternative & Punk', 'Green Day', 'Brazil', 1),
#  ('Metal', 'Bruce Dickinson', 'USA', 1),
#  ('Rock', 'Jimi Hendrix', 'Czech Republic', 1),
#  ('Classical', 'Emerson String Quartet', 'Italy', 1),
#  ('Rock', 'Rush', 'Canada', 1),
#  ('Rock', "Paul D'Ianno", 'France', 1),
#  ('Classical', 'Adrian Leaper & Doreen de Feis', 'USA', 1),
#  ('World', 'Mônica Marianno', 'Sweden', 1),
#  ('Rock', 'Frank Zappa & Captain Beefheart', 'USA', 1),
#  ('Rock', 'Led Zeppelin', 'Finland', 1),
#  ('Alternative & Punk', 'Audioslave', 'France', 1),
#  ('Rock', 'Deep Purple', 'France', 1),
#  ('Alternative & Punk', 'JET', 'Portugal', 1),
#  ('Rock', 'Jamiroquai', 'Canada', 1),
#  ('Latin', 'Marcos Valle', 'Brazil', 1),
#  ('Latin', 'Olodum', 'Czech Republic', 1),
#  ('Metal', 'Judas Priest', 'Portugal', 1),
#  ('Blues', 'Iron Maiden', 'Germany', 1),
#  ('Rock', 'AC/DC', 'United Kingdom', 1),
#  ('Blues', 'Iron Maiden', 'Portugal', 1),
#  ('Jazz', 'Gilberto Gil', 'USA', 1),
#  ('Blues', 'Stevie Ray Vaughan & Double Trouble', 'Ireland', 1),
#  ('Rock', 'Velvet Revolver', 'Finland', 1),
#  ('Classical', 'Emanuel Ax, Eugene Ormandy & Philadelphia Orchestra', 'India', 1),
#  ('Rock', 'Joe Satriani', 'United Kingdom', 1),
#  ('Alternative & Punk', 'Foo Fighters', 'USA', 1),
#  ('Rock', 'The Police', 'Belgium', 1),
#  ('Rock', 'Iron Maiden', 'Hungary', 1),
#  ('Drama', 'Lost', 'Austria', 1),
#  ('TV Shows', 'Aquaman', 'Portugal', 1),
#  ('Classical', 'Yo-Yo Ma', 'France', 1),
#  ('Reggae', 'Cidade Negra', 'France', 1),
#  ('Rock', 'Iron Maiden', 'Poland', 1),
#  ('Rock', 'Van Halen', 'Canada', 1),
#  ('Sci Fi & Fantasy', 'Battlestar Galactica', 'USA', 1),
#  ('Classical', "The King's Singers", 'France', 1),
#  ('Classical', 'Edo de Waart & San Francisco Symphony', 'Norway', 1),
#  ('Classical', 'Eugene Ormandy', 'Norway', 1),
#  ('Alternative & Punk', 'Foo Fighters', 'Germany', 1),
#  ('Classical', 'Equale Brass Ensemble, John Eliot Gardiner & Munich Monteverdi Orchestra and Choir', 'Brazil', 1),
#  ('Rock', 'Creedence Clearwater Revival', 'United Kingdom', 1),
#  ('Metal', 'Godsmack', 'France', 1),
#  ('Rock', 'Kiss', 'Portugal', 1),
#  ('Rock', 'Led Zeppelin', 'India', 1),
#  ('Classical', 'Roger Norrington, London Classical Players', 'France', 1),
#  ('Alternative & Punk', 'Pearl Jam', 'Brazil', 1),
#  ('Alternative & Punk', 'Foo Fighters', 'Argentina', 1),
#  ('Blues', 'Iron Maiden', 'Australia', 1),
#  ('Rock', 'Santana', 'Poland', 1),
#  ('Sci Fi & Fantasy', 'Battlestar Galactica (Classic)', 'India', 1),
#  ('Rock', 'Frank Zappa & Captain Beefheart', 'Germany', 1),
#  ('Sci Fi & Fantasy', 'Battlestar Galactica (Classic)', 'Hungary', 1),
#  ('Alternative & Punk', 'Green Day', 'Sweden', 1),
#  ('Classical', 'Otto Klemperer & Philharmonia Orchestra', 'France', 1),
#  ('Classical', 'Equale Brass Ensemble, John Eliot Gardiner & Munich Monteverdi Orchestra and Choir', 'France', 1),
#  ('Classical', 'Göteborgs Symfoniker & Neeme Järvi', 'Brazil', 1),
#  ('Classical', 'Academy of St. Martin in the Fields, Sir Neville Marriner & Thurston Dart', 'Brazil', 1),
#  ('Rock', 'Men At Work', 'Canada', 1),
#  ('Latin', 'Vinícius De Moraes', 'Hungary', 1),
#  ('Alternative & Punk', 'The Clash', 'Italy', 1),
#  ('Latin', 'Cláudio Zoli', 'France', 1),
#  ('Alternative', 'Chris Cornell', 'USA', 1),
#  ('Latin', 'Vinícius De Moraes', 'Czech Republic', 1),
#  ('Classical', 'Philharmonia Orchestra & Sir Neville Marriner', 'USA', 1),
#  ('Alternative & Punk', 'Raimundos', 'USA', 1),
#  ('Rock', 'Velvet Revolver', 'USA', 1),
#  ('Metal', 'Bruce Dickinson', 'Germany', 1),
#  ('Metal', 'Metallica', 'Belgium', 1),
#  ('Classical', 'Scholars Baroque Ensemble', 'USA', 1),
#  ('Rock', 'Dread Zeppelin', 'France', 1),
#  ('Alternative & Punk', 'Body Count', 'Hungary', 1),
#  ('Jazz', 'Antônio Carlos Jobim', 'France', 1),
#  ('Rock', 'David Coverdale', 'France', 1),
#  ('Rock', 'Lenny Kravitz', 'United Kingdom', 1),
#  ('Classical', 'Eugene Ormandy', 'Canada', 1),
#  ('Jazz', 'Antônio Carlos Jobim', 'United Kingdom', 1),
#  ('Classical', 'Maurizio Pollini', 'USA', 1),
#  ('Pop', 'Amy Winehouse', 'Brazil', 1),
#  ('Drama', 'Heroes', 'Germany', 1),
#  ('Pop', 'Various Artists', 'USA', 1),
#  ('Rock', 'Pink Floyd', 'Spain', 1),
#  ('Electronica/Dance', 'Jamiroquai', 'Hungary', 1),
#  ('Electronica/Dance', 'Jamiroquai', 'Canada', 1),
#  ('Alternative & Punk', 'R.E.M.', 'Czech Republic', 1),
#  ('TV Shows', 'Battlestar Galactica', 'USA', 1),
#  ('Metal', 'Metallica', 'Portugal', 1),
#  ('Metal', 'Metallica', 'Italy', 1),
#  ('Alternative & Punk', 'R.E.M. Feat. Kate Pearson', 'India', 1),
#  ('Alternative & Punk', 'Os Mutantes', 'USA', 1),
#  ('Soundtrack', 'Gilberto Gil', 'Argentina', 1),
#  ('Rock', 'Frank Zappa & Captain Beefheart', 'France', 1),
#  ('TV Shows', 'The Office', 'India', 1),
#  ('TV Shows', 'Battlestar Galactica', 'Germany', 1),
#  ('Rock', 'Kiss', 'Netherlands', 1),
#  ('Soundtrack', 'Gilberto Gil', 'Chile', 1),
#  ('Blues', 'Eric Clapton', 'Brazil', 1),
#  ('Metal', 'Ozzy Osbourne', 'France', 1),
#  ('Rock', 'Ozzy Osbourne', 'Brazil', 1),
#  ('Rock', 'Pink Floyd', 'Canada', 1),
#  ('Alternative', 'Chris Cornell', 'France', 1),
#  ('Drama', 'Lost', 'Hungary', 1),
#  ('Latin', 'Olodum', 'Canada', 1),
#  ('Latin', 'Os Paralamas Do Sucesso', 'Ireland', 1),
#  ('Latin', 'Ed Motta', 'India', 1),
#  ('Rock', 'Rush', 'France', 1),
#  ('Rock', 'Page & Plant', 'Brazil', 1),
#  ('Classical', "Kent Nagano and Orchestre de l'Opéra de Lyon", 'USA', 1),
#  ('Rock', 'Led Zeppelin', 'Denmark', 1),
#  ('Drama', 'Heroes', 'France', 1),
#  ('Classical', 'Chicago Symphony Orchestra & Fritz Reiner', 'Norway', 1),
#  ('Jazz', 'Gilberto Gil', 'Germany', 1),
#  ('Latin', 'Tim Maia', 'Spain', 1),
#  ('Rock', 'Queen', 'Poland', 1),
#  ('World', 'João Suplicy', 'United Kingdom', 1),
#  ('Metal', 'Apocalyptica', 'USA', 1),
#  ('Alternative', 'Audioslave', 'Norway', 1),
#  ('Hip Hop/Rap', 'Planet Hemp', 'Spain', 1),
#  ('Jazz', 'Spyro Gyra', 'France', 1),
#  ('Alternative', 'Temple of the Dog', 'Norway', 1),
#  ('Alternative & Punk', 'R.E.M.', 'Poland', 1),
#  ('Alternative & Punk', 'Faith No More', 'Canada', 1),
#  ('Latin', 'Jota Quest', 'Portugal', 1),
#  ('Classical', 'Emerson String Quartet', 'Brazil', 1),
#  ('Classical', 'Michael Tilson Thomas & San Francisco Symphony', 'USA', 1),
#  ('Drama', 'Lost', 'Chile', 1),
#  ('Alternative & Punk', 'Os Mutantes', 'India', 1),
#  ('Rock', 'Accept', 'Canada', 1),
#  ('TV Shows', 'Battlestar Galactica', 'Sweden', 1),
#  ('Jazz', 'Dennis Chambers', 'Germany', 1),
#  ('Classical', 'Orchestra of The Age of Enlightenment', 'India', 1),
#  ('Latin', 'Luciana Souza/Romero Lubambo', 'USA', 1),
#  ('Latin', 'Cláudio Zoli', 'Brazil', 1),
#  ('Alternative & Punk', 'Titãs', 'Czech Republic', 1),
#  ('Bossa Nova', 'Toquinho & Vinícius', 'France', 1),
#  ('Classical', 'Academy of St. Martin in the Fields, Sir Neville Marriner & Thurston Dart', 'France', 1),
#  ('Classical', 'Martin Roscoe', 'USA', 1),
#  ('Jazz', 'Spyro Gyra', 'Poland', 1),
#  ('Blues', 'Iron Maiden', 'USA', 1),
#  ('Jazz', 'Billy Cobham', 'Canada', 1),
#  ('Rock', 'Velvet Revolver', 'Hungary', 1),
#  ('Metal', 'Motörhead', 'Brazil', 1),
#  ('Alternative & Punk', 'The Clash', 'Germany', 1),
#  ('Latin', 'Olodum', 'Spain', 1),
#  ('Rock', 'Jamiroquai', 'USA', 1),
#  ('Electronica/Dance', 'Jamiroquai', 'Portugal', 1),
#  ('Blues', 'Buddy Guy', 'Czech Republic', 1),
#  ('Jazz', 'Miles Davis', 'Sweden', 1),
#  ('Rock And Roll', 'BackBeat', 'France', 1),
#  ('Classical', 'English Concert & Trevor Pinnock', 'Norway', 1),
#  ('Rock', 'Stone Temple Pilots', 'Canada', 1),
#  ('Alternative & Punk', 'Os Mutantes', 'Brazil', 1),
#  ('R&B/Soul', 'Jamiroquai', 'Canada', 1),
#  ('Blues', 'Stevie Ray Vaughan & Double Trouble', 'Poland', 1),
#  ('Classical', 'The 12 Cellists of The Berlin Philharmonic', 'France', 1)]
